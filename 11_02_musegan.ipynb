# %%
# Run Date: Monday, June 05, 2023
# Run Time: 03:55:37

# %%
import time
from datetime import date

startTime = time.time()
todaysDate = date.today()

# %% [markdown]
# # 🎶 Music Generation - MuseGAN

# %% [markdown]
# In this notebook, we'll walk through the steps required to train your own MuseGAN model to generate music in the style of the Bach chorales

# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np
import matplotlib.pyplot as plt

plt.style.use("seaborn-v0_8-colorblind")

import os
import tensorflow as tf
from tensorflow.keras import (
    layers,
    models,
    optimizers,
    callbacks,
    initializers,
    metrics,
)

from musegan_utils import notes_to_midi, draw_score
# Out:
# 2023-06-05 19:54:40.898049: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-06-05 19:54:41.011036: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %% [markdown]
# ## 0. Parameters <a name="parameters"></a>

# %%
BATCH_SIZE = 64

N_BARS = 2
N_STEPS_PER_BAR = 16
MAX_PITCH = 83
N_PITCHES = MAX_PITCH + 1
Z_DIM = 32


CRITIC_STEPS = 5
GP_WEIGHT = 10
CRITIC_LEARNING_RATE = 0.001
GENERATOR_LEARNING_RATE = 0.001
ADAM_BETA_1 = 0.5
ADAM_BETA_2 = 0.9
EPOCHS = 6000
LOAD_MODEL = False

# %% [markdown]
# ## 1. Prepare the Data

# %%
dataFolder = '/tf/All/Data/Documents/Github/davidADSP/data/Bach-Chorales'

# %%
# Load the data
file = os.path.join(dataFolder + "/Jsb16thSeparated.npz")
with np.load(file, encoding="bytes", allow_pickle=True) as f:
    data = f["train"]

# %%
N_SONGS = len(data)
print(f"{N_SONGS} chorales in the dataset")
chorale = data[0]
N_BEATS, N_TRACKS = chorale.shape
print(f"{N_BEATS, N_TRACKS} shape of chorale 0")
print("\nChorale 0")
print(chorale[:8])
# Out:
# 229 chorales in the dataset
# (192, 4) shape of chorale 0
#
# Chorale 0
# [[74. 70. 65. 58.]
#  [74. 70. 65. 58.]
#  [74. 70. 65. 58.]
#  [74. 70. 65. 58.]
#  [75. 70. 58. 55.]
#  [75. 70. 58. 55.]
#  [75. 70. 60. 55.]
#  [75. 70. 60. 55.]]

# %%
two_bars = np.array([x[: (N_STEPS_PER_BAR * N_BARS)] for x in data])
two_bars = np.array(np.nan_to_num(two_bars, nan=MAX_PITCH), dtype=int)
two_bars = two_bars.reshape([N_SONGS, N_BARS, N_STEPS_PER_BAR, N_TRACKS])
print(f"Two bars shape {two_bars.shape}")
# Out:
# Two bars shape (229, 2, 16, 4)

# %%
data_binary = np.eye(N_PITCHES)[two_bars]
data_binary[data_binary == 0] = -1
data_binary = data_binary.transpose([0, 1, 2, 4, 3])
print(f"Data binary shape {data_binary.shape}")
# Out:
# Data binary shape (229, 2, 16, 84, 4)

# %% [markdown]
# ## 2. Build the GAN <a name="build"></a>

# %%
# Some helper functions

initializer = initializers.RandomNormal(mean=0.0, stddev=0.02)


def conv(x, f, k, s, p):
    x = layers.Conv3D(
        filters=f,
        kernel_size=k,
        padding=p,
        strides=s,
        kernel_initializer=initializer,
    )(x)
    x = layers.LeakyReLU()(x)
    return x


def conv_t(x, f, k, s, a, p, bn):
    x = layers.Conv2DTranspose(
        filters=f,
        kernel_size=k,
        padding=p,
        strides=s,
        kernel_initializer=initializer,
    )(x)
    if bn:
        x = layers.BatchNormalization(momentum=0.9)(x)

    x = layers.Activation(a)(x)
    return x

# %%
def TemporalNetwork():
    input_layer = layers.Input(shape=(Z_DIM,), name="temporal_input")
    x = layers.Reshape([1, 1, Z_DIM])(input_layer)
    x = conv_t(x, f=1024, k=(2, 1), s=(1, 1), a="relu", p="valid", bn=True)
    x = conv_t(
        x, f=Z_DIM, k=(N_BARS - 1, 1), s=(1, 1), a="relu", p="valid", bn=True
    )
    output_layer = layers.Reshape([N_BARS, Z_DIM])(x)
    return models.Model(input_layer, output_layer)


TemporalNetwork().summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  temporal_input (InputLayer)  [(None, 32)]             0
#
#  reshape (Reshape)           (None, 1, 1, 32)          0
#
#  conv2d_transpose (Conv2DTra  (None, 2, 1, 1024)       66560
#  nspose)
#
#  batch_normalization (BatchN  (None, 2, 1, 1024)       4096
#  ormalization)
#
#  activation (Activation)     (None, 2, 1, 1024)        0
#
#  conv2d_transpose_1 (Conv2DT  (None, 2, 1, 32)         32800
#  ranspose)
#
#  batch_normalization_1 (Batc  (None, 2, 1, 32)         128
#  hNormalization)
#
#  activation_1 (Activation)   (None, 2, 1, 32)          0
#
#  reshape_1 (Reshape)         (None, 2, 32)             0
#
# =================================================================
# Total params: 103,584
# Trainable params: 101,472
# Non-trainable params: 2,112
# _________________________________________________________________
# 2023-06-05 19:54:42.945214: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-06-05 19:54:42.945400: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-06-05 19:54:42.947245: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-06-05 19:54:42.947397: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-06-05 19:54:42.947572: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-06-05 19:54:42.947708: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-06-05 19:54:42.947824: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2006] Ignoring visible gpu device (device: 1, name: NVIDIA GeForce GTX 1050, pci bus id: 0000:01:00.0, compute capability: 6.1) with core count: 5. The minimum required count is 8. You can adjust this requirement with the env var TF_MIN_GPU_MULTIPROCESSOR_COUNT.
# 2023-06-05 19:54:42.948049: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-06-05 19:54:42.948369: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-06-05 19:54:42.948518: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-06-05 19:54:42.948715: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-06-05 19:54:43.414243: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-06-05 19:54:43.414480: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-06-05 19:54:43.414623: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-06-05 19:54:43.414754: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1616] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 6649 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 2070 SUPER, pci bus id: 0000:02:00.0, compute capability: 7.5
# /usr/local/lib/python3.8/dist-packages/keras/initializers/initializers_v2.py:120: UserWarning: The initializer RandomNormal is unseeded and being called multiple times, which will return identical values  each time (even if the initializer is unseeded). Please update your code to provide a seed to the initializer, or avoid using the same initalizer instance more than once.
#   warnings.warn(

# %%
def BarGenerator():
    input_layer = layers.Input(shape=(Z_DIM * 4,), name="bar_generator_input")

    x = layers.Dense(1024)(input_layer)
    x = layers.BatchNormalization(momentum=0.9)(x)
    x = layers.Activation("relu")(x)
    x = layers.Reshape([2, 1, 512])(x)

    x = conv_t(x, f=512, k=(2, 1), s=(2, 1), a="relu", p="same", bn=True)
    x = conv_t(x, f=256, k=(2, 1), s=(2, 1), a="relu", p="same", bn=True)
    x = conv_t(x, f=256, k=(2, 1), s=(2, 1), a="relu", p="same", bn=True)
    x = conv_t(x, f=256, k=(1, 7), s=(1, 7), a="relu", p="same", bn=True)
    x = conv_t(x, f=1, k=(1, 12), s=(1, 12), a="tanh", p="same", bn=False)

    output_layer = layers.Reshape([1, N_STEPS_PER_BAR, N_PITCHES, 1])(x)

    return models.Model(input_layer, output_layer)


BarGenerator().summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bar_generator_input (InputL  [(None, 128)]            0
#  ayer)
#
#  dense (Dense)               (None, 1024)              132096
#
#  batch_normalization_2 (Batc  (None, 1024)             4096
#  hNormalization)
#
#  activation_2 (Activation)   (None, 1024)              0
#
#  reshape_2 (Reshape)         (None, 2, 1, 512)         0
#
#  conv2d_transpose_2 (Conv2DT  (None, 4, 1, 512)        524800
#  ranspose)
#
#  batch_normalization_3 (Batc  (None, 4, 1, 512)        2048
#  hNormalization)
#
#  activation_3 (Activation)   (None, 4, 1, 512)         0
#
#  conv2d_transpose_3 (Conv2DT  (None, 8, 1, 256)        262400
#  ranspose)
#
#  batch_normalization_4 (Batc  (None, 8, 1, 256)        1024
#  hNormalization)
#
#  activation_4 (Activation)   (None, 8, 1, 256)         0
#
#  conv2d_transpose_4 (Conv2DT  (None, 16, 1, 256)       131328
#  ranspose)
#
#  batch_normalization_5 (Batc  (None, 16, 1, 256)       1024
#  hNormalization)
#
#  activation_5 (Activation)   (None, 16, 1, 256)        0
#
#  conv2d_transpose_5 (Conv2DT  (None, 16, 7, 256)       459008
#  ranspose)
#
#  batch_normalization_6 (Batc  (None, 16, 7, 256)       1024
#  hNormalization)
#
#  activation_6 (Activation)   (None, 16, 7, 256)        0
#
#  conv2d_transpose_6 (Conv2DT  (None, 16, 84, 1)        3073
#  ranspose)
#
#  activation_7 (Activation)   (None, 16, 84, 1)         0
#
#  reshape_3 (Reshape)         (None, 1, 16, 84, 1)      0
#
# =================================================================
# Total params: 1,521,921
# Trainable params: 1,517,313
# Non-trainable params: 4,608
# _________________________________________________________________

# %%
def Generator():
    chords_input = layers.Input(shape=(Z_DIM,), name="chords_input")
    style_input = layers.Input(shape=(Z_DIM,), name="style_input")
    melody_input = layers.Input(shape=(N_TRACKS, Z_DIM), name="melody_input")
    groove_input = layers.Input(shape=(N_TRACKS, Z_DIM), name="groove_input")

    # CHORDS -> TEMPORAL NETWORK
    chords_tempNetwork = TemporalNetwork()
    chords_over_time = chords_tempNetwork(chords_input)  # [n_bars, z_dim]

    # MELODY -> TEMPORAL NETWORK
    melody_over_time = [
        None
    ] * N_TRACKS  # list of n_tracks [n_bars, z_dim] tensors
    melody_tempNetwork = [None] * N_TRACKS
    for track in range(N_TRACKS):
        melody_tempNetwork[track] = TemporalNetwork()
        melody_track = layers.Lambda(lambda x, track=track: x[:, track, :])(
            melody_input
        )
        melody_over_time[track] = melody_tempNetwork[track](melody_track)

    # CREATE BAR GENERATOR FOR EACH TRACK
    barGen = [None] * N_TRACKS
    for track in range(N_TRACKS):
        barGen[track] = BarGenerator()

    # CREATE OUTPUT FOR EVERY TRACK AND BAR
    bars_output = [None] * N_BARS
    c = [None] * N_BARS
    for bar in range(N_BARS):
        track_output = [None] * N_TRACKS

        c[bar] = layers.Lambda(lambda x, bar=bar: x[:, bar, :])(
            chords_over_time
        )  # [z_dim]
        s = style_input  # [z_dim]

        for track in range(N_TRACKS):
            m = layers.Lambda(lambda x, bar=bar: x[:, bar, :])(
                melody_over_time[track]
            )  # [z_dim]
            g = layers.Lambda(lambda x, track=track: x[:, track, :])(
                groove_input
            )  # [z_dim]

            z_input = layers.Concatenate(
                axis=1, name="total_input_bar_{}_track_{}".format(bar, track)
            )([c[bar], s, m, g])

            track_output[track] = barGen[track](z_input)

        bars_output[bar] = layers.Concatenate(axis=-1)(track_output)

    generator_output = layers.Concatenate(axis=1, name="concat_bars")(
        bars_output
    )

    return models.Model(
        [chords_input, style_input, melody_input, groove_input],
        generator_output,
    )


generator = Generator()
# generator.summary()

# %%
def Critic():
    critic_input = layers.Input(
        shape=(N_BARS, N_STEPS_PER_BAR, N_PITCHES, N_TRACKS),
        name="critic_input",
    )

    x = critic_input

    x = conv(x, f=128, k=(2, 1, 1), s=(1, 1, 1), p="valid")
    x = conv(x, f=128, k=(N_BARS - 1, 1, 1), s=(1, 1, 1), p="valid")
    x = conv(x, f=128, k=(1, 1, 12), s=(1, 1, 12), p="same")
    x = conv(x, f=128, k=(1, 1, 7), s=(1, 1, 7), p="same")
    x = conv(x, f=128, k=(1, 2, 1), s=(1, 2, 1), p="same")
    x = conv(x, f=128, k=(1, 2, 1), s=(1, 2, 1), p="same")
    x = conv(x, f=256, k=(1, 4, 1), s=(1, 2, 1), p="same")
    x = conv(x, f=512, k=(1, 3, 1), s=(1, 2, 1), p="same")

    x = layers.Flatten()(x)

    x = layers.Dense(1024, kernel_initializer=initializer)(x)
    x = layers.LeakyReLU()(x)

    critic_output = layers.Dense(
        1, activation=None, kernel_initializer=initializer
    )(x)

    return models.Model(critic_input, critic_output)


critic = Critic()
# critic.summary()

# %%
class MuseGAN(models.Model):
    def __init__(self, critic, generator, latent_dim, critic_steps, gp_weight):
        super(MuseGAN, self).__init__()
        self.critic = critic
        self.generator = generator
        self.latent_dim = latent_dim
        self.critic_steps = critic_steps
        self.gp_weight = gp_weight

    def compile(self, c_optimizer, g_optimizer):
        super(MuseGAN, self).compile()
        self.c_optimizer = c_optimizer
        self.g_optimizer = g_optimizer
        self.c_wass_loss_metric = metrics.Mean(name="c_wass_loss")
        self.c_gp_metric = metrics.Mean(name="c_gp")
        self.c_loss_metric = metrics.Mean(name="c_loss")
        self.g_loss_metric = metrics.Mean(name="g_loss")

    @property
    def metrics(self):
        return [
            self.c_loss_metric,
            self.c_wass_loss_metric,
            self.c_gp_metric,
            self.g_loss_metric,
        ]

    def gradient_penalty(self, batch_size, real_images, fake_images):
        alpha = tf.random.normal([batch_size, 1, 1, 1, 1], 0.0, 1.0)
        diff = fake_images - real_images
        interpolated = real_images + alpha * diff

        with tf.GradientTape() as gp_tape:
            gp_tape.watch(interpolated)
            pred = self.critic(interpolated, training=True)

        grads = gp_tape.gradient(pred, [interpolated])[0]
        norm = tf.sqrt(tf.reduce_sum(tf.square(grads), axis=[1, 2, 3]))
        gp = tf.reduce_mean((norm - 1.0) ** 2)
        return gp

    def train_step(self, real_images):
        batch_size = tf.shape(real_images)[0]

        for i in range(self.critic_steps):
            chords_random_latent_vectors = tf.random.normal(
                shape=(batch_size, self.latent_dim)
            )
            style_random_latent_vectors = tf.random.normal(
                shape=(batch_size, self.latent_dim)
            )
            melody_random_latent_vectors = tf.random.normal(
                shape=(batch_size, N_TRACKS, self.latent_dim)
            )
            groove_random_latent_vectors = tf.random.normal(
                shape=(batch_size, N_TRACKS, self.latent_dim)
            )

            random_latent_vectors = [
                chords_random_latent_vectors,
                style_random_latent_vectors,
                melody_random_latent_vectors,
                groove_random_latent_vectors,
            ]

            with tf.GradientTape() as tape:
                fake_images = self.generator(
                    random_latent_vectors, training=True
                )
                fake_predictions = self.critic(fake_images, training=True)
                real_predictions = self.critic(real_images, training=True)

                c_wass_loss = tf.reduce_mean(fake_predictions) - tf.reduce_mean(
                    real_predictions
                )
                c_gp = self.gradient_penalty(
                    batch_size, real_images, fake_images
                )
                c_loss = c_wass_loss + c_gp * self.gp_weight

            c_gradient = tape.gradient(c_loss, self.critic.trainable_variables)
            self.c_optimizer.apply_gradients(
                zip(c_gradient, self.critic.trainable_variables)
            )

        chords_random_latent_vectors = tf.random.normal(
            shape=(batch_size, self.latent_dim)
        )
        style_random_latent_vectors = tf.random.normal(
            shape=(batch_size, self.latent_dim)
        )
        melody_random_latent_vectors = tf.random.normal(
            shape=(batch_size, N_TRACKS, self.latent_dim)
        )
        groove_random_latent_vectors = tf.random.normal(
            shape=(batch_size, N_TRACKS, self.latent_dim)
        )

        random_latent_vectors = [
            chords_random_latent_vectors,
            style_random_latent_vectors,
            melody_random_latent_vectors,
            groove_random_latent_vectors,
        ]

        with tf.GradientTape() as tape:
            fake_images = self.generator(random_latent_vectors, training=True)
            fake_predictions = self.critic(fake_images, training=True)
            g_loss = -tf.reduce_mean(fake_predictions)

        gen_gradient = tape.gradient(g_loss, self.generator.trainable_variables)
        self.g_optimizer.apply_gradients(
            zip(gen_gradient, self.generator.trainable_variables)
        )

        self.c_loss_metric.update_state(c_loss)
        self.c_wass_loss_metric.update_state(c_wass_loss)
        self.c_gp_metric.update_state(c_gp)
        self.g_loss_metric.update_state(g_loss)

        return {m.name: m.result() for m in self.metrics}

    def generate_piano_roll(self, num_scores):
        chords_random_latent_vectors = tf.random.normal(
            shape=(num_scores, Z_DIM)
        )
        style_random_latent_vectors = tf.random.normal(
            shape=(num_scores, Z_DIM)
        )
        melody_random_latent_vectors = tf.random.normal(
            shape=(num_scores, N_TRACKS, Z_DIM)
        )
        groove_random_latent_vectors = tf.random.normal(
            shape=(num_scores, N_TRACKS, Z_DIM)
        )
        random_latent_vectors = [
            chords_random_latent_vectors,
            style_random_latent_vectors,
            melody_random_latent_vectors,
            groove_random_latent_vectors,
        ]
        generated_music = self.generator(random_latent_vectors)
        generated_music = generated_music.numpy()
        return generated_music

# %%
# Create a MuseGAN
musegan = MuseGAN(
    critic=critic,
    generator=generator,
    latent_dim=Z_DIM,
    critic_steps=CRITIC_STEPS,
    gp_weight=GP_WEIGHT,
)

# %%
if LOAD_MODEL:
    musegan.load_weights("11_02_musegan/checkpoint/checkpoint.ckpt")

# %% [markdown]
# ## 3. Train the MuseGAN <a name="train"></a>

# %%
# Compile the GAN
musegan.compile(
    c_optimizer=optimizers.Adam(
        learning_rate=CRITIC_LEARNING_RATE,
        beta_1=ADAM_BETA_1,
        beta_2=ADAM_BETA_2,
    ),
    g_optimizer=optimizers.Adam(
        learning_rate=GENERATOR_LEARNING_RATE,
        beta_1=ADAM_BETA_1,
        beta_2=ADAM_BETA_2,
    ),
)

# %%
# Create a model save checkpoint
model_checkpoint_callback = callbacks.ModelCheckpoint(
    filepath="11_02_musegan/checkpoint/checkpoint.ckpt",
    save_weights_only=True,
    save_freq="epoch",
    verbose=0,
)

tensorboard_callback = callbacks.TensorBoard(log_dir="11_02_musegan/logs")


class MusicGenerator(callbacks.Callback):
    def __init__(self, num_scores):
        self.num_scores = num_scores

    def on_epoch_end(self, epoch, logs=None):
        if epoch % 1 == 0:
            generated_music = self.model.generate_piano_roll(self.num_scores)
            notes_to_midi(
                generated_music,
                N_BARS,
                N_TRACKS,
                N_STEPS_PER_BAR,
                filename="output_" + str(epoch).zfill(4),
            )
            # display(generated_images, save_to = "./output/generated_img_%03d.png" % (epoch), cmap = None)


music_generator_callback = MusicGenerator(1)

# %%
# %%time
history = musegan.fit(
    data_binary,
    epochs=EPOCHS,
    callbacks=[
        model_checkpoint_callback,
        tensorboard_callback,
        music_generator_callback,
    ],
)
# Out:
# Epoch 1/6000
# 2023-06-05 19:55:11.335515: I tensorflow/stream_executor/cuda/cuda_dnn.cc:384] Loaded cuDNN version 8100
# 8/8 [==============================] - 30s 327ms/step - c_loss: -392.5236 - c_wass_loss: -1200.7277 - c_gp: 80.8204 - g_loss: -191.2320
# Epoch 2/6000
# 8/8 [==============================] - 2s 280ms/step - c_loss: -123.5182 - c_wass_loss: -191.8484 - c_gp: 6.8330 - g_loss: -457.5372
# Epoch 3/6000
# 8/8 [==============================] - 2s 279ms/step - c_loss: -62.4154 - c_wass_loss: -94.3695 - c_gp: 3.1954 - g_loss: -1476.2113
# Epoch 4/6000
# 8/8 [==============================] - 2s 281ms/step - c_loss: -64.5141 - c_wass_loss: -106.6722 - c_gp: 4.2158 - g_loss: -1023.7485
# Epoch 5/6000
# 8/8 [==============================] - 2s 280ms/step - c_loss: -70.1530 - c_wass_loss: -104.5818 - c_gp: 3.4429 - g_loss: -864.0012
# Epoch 6/6000
# 8/8 [==============================] - 2s 281ms/step - c_loss: -68.6161 - c_wass_loss: -97.1404 - c_gp: 2.8524 - g_loss: -809.7181
# Epoch 7/6000
# 8/8 [==============================] - 2s 281ms/step - c_loss: -71.3868 - c_wass_loss: -107.8863 - c_gp: 3.6499 - g_loss: -759.6000
# Epoch 8/6000
# 8/8 [==============================] - 2s 280ms/step - c_loss: -73.6902 - c_wass_loss: -105.0538 - c_gp: 3.1364 - g_loss: -662.2663
# Epoch 9/6000
# 8/8 [==============================] - 2s 279ms/step - c_loss: -54.3135 - c_wass_loss: -79.6477 - c_gp: 2.5334 - g_loss: -559.5968
# Epoch 10/6000
# 8/8 [==============================] - 2s 277ms/step - c_loss: -38.3452 - c_wass_loss: -56.8145 - c_gp: 1.8469 - g_loss: -512.9020
# Epoch 11/6000
# 8/8 [==============================] - 2s 282ms/step - c_loss: -28.2398 - c_wass_loss: -40.7566 - c_gp: 1.2517 - g_loss: -522.3868
# Epoch 12/6000
# 8/8 [==============================] - 2s 278ms/step - c_loss: -25.1021 - c_wass_loss: -34.2490 - c_gp: 0.9147 - g_loss: -537.9393
# Epoch 13/6000
# 8/8 [==============================] - 2s 279ms/step - c_loss: -19.4962 - c_wass_loss: -28.1800 - c_gp: 0.8684 - g_loss: -350.6767
# Epoch 14/6000
# 8/8 [==============================] - 2s 308ms/step - c_loss: -19.8311 - c_wass_loss: -25.4752 - c_gp: 0.5644 - g_loss: -338.0154
# Epoch 15/6000
# 8/8 [==============================] - 2s 277ms/step - c_loss: -18.5179 - c_wass_loss: -23.1972 - c_gp: 0.4679 - g_loss: -321.0659
# Epoch 16/6000
# 8/8 [==============================] - 2s 278ms/step - c_loss: -21.3008 - c_wass_loss: -30.5489 - c_gp: 0.9248 - g_loss: -339.8317
# Epoch 17/6000
# 8/8 [==============================] - 2s 281ms/step - c_loss: -31.2450 - c_wass_loss: -46.4236 - c_gp: 1.5179 - g_loss: -452.3109
# Epoch 18/6000
# 8/8 [==============================] - 2s 283ms/step - c_loss: -42.4871 - c_wass_loss: -59.8563 - c_gp: 1.7369 - g_loss: -486.7826
# Epoch 19/6000
# 8/8 [==============================] - 2s 277ms/step - c_loss: -44.4518 - c_wass_loss: -64.4874 - c_gp: 2.0036 - g_loss: -306.8076
# Epoch 20/6000
# 8/8 [==============================] - 2s 278ms/step - c_loss: -51.5549 - c_wass_loss: -69.1036 - c_gp: 1.7549 - g_loss: -215.2902
# Epoch 21/6000
# 8/8 [==============================] - 2s 282ms/step - c_loss: -55.5488 - c_wass_loss: -87.2643 - c_gp: 3.1715 - g_loss: -213.4893
# Epoch 22/6000
# 8/8 [==============================] - 2s 276ms/step - c_loss: -52.9658 - c_wass_loss: -71.5488 - c_gp: 1.8583 - g_loss: -190.4474
# Epoch 23/6000
# 8/8 [==============================] - 2s 279ms/step - c_loss: -52.4190 - c_wass_loss: -73.9931 - c_gp: 2.1574 - g_loss: -147.3872
# Epoch 24/6000
# 8/8 [==============================] - 2s 280ms/step - c_loss: -53.7898 - c_wass_loss: -89.3706 - c_gp: 3.5581 - g_loss: -174.6079
# Epoch 25/6000
# 8/8 [==============================] - 2s 281ms/step - c_loss: -55.0779 - c_wass_loss: -93.6092 - c_gp: 3.8531 - g_loss: -176.5473
# Epoch 26/6000
# 8/8 [==============================] - 2s 282ms/step - c_loss: -53.0042 - c_wass_loss: -80.7323 - c_gp: 2.7728 - g_loss: -272.4304
# Epoch 27/6000
# 8/8 [==============================] - 2s 283ms/step - c_loss: -57.0734 - c_wass_loss: -82.0466 - c_gp: 2.4973 - g_loss: -223.9090
# Epoch 28/6000
# 8/8 [==============================] - 2s 282ms/step - c_loss: -51.3677 - c_wass_loss: -81.4014 - c_gp: 3.0034 - g_loss: -191.1578
# Epoch 29/6000
# 8/8 [==============================] - 2s 283ms/step - c_loss: -50.6432 - c_wass_loss: -78.0430 - c_gp: 2.7400 - g_loss: -272.3307
# Epoch 30/6000
# 8/8 [==============================] - 2s 282ms/step - c_loss: -54.8954 - c_wass_loss: -83.2993 - c_gp: 2.8404 - g_loss: -189.5075
# Epoch 31/6000
# 8/8 [==============================] - 2s 276ms/step - c_loss: -54.8414 - c_wass_loss: -90.8745 - c_gp: 3.6033 - g_loss: -221.2672
# Epoch 32/6000
# 8/8 [==============================] - 2s 280ms/step - c_loss: -54.6938 - c_wass_loss: -71.3050 - c_gp: 1.6611 - g_loss: -259.4715
# Epoch 33/6000
# 8/8 [==============================] - 2s 279ms/step - c_loss: -52.5731 - c_wass_loss: -72.5548 - c_gp: 1.9982 - g_loss: -161.1756
# Epoch 34/6000
# 8/8 [==============================] - 2s 278ms/step - c_loss: -49.7403 - c_wass_loss: -75.1130 - c_gp: 2.5373 - g_loss: -189.5302
# Epoch 35/6000
# 8/8 [==============================] - 2s 281ms/step - c_loss: -54.7080 - c_wass_loss: -81.4193 - c_gp: 2.6711 - g_loss: -336.3142
# Epoch 36/6000
# 8/8 [==============================] - 2s 307ms/step - c_loss: -53.3697 - c_wass_loss: -85.6838 - c_gp: 3.2314 - g_loss: -202.8081
# Epoch 37/6000
# 8/8 [==============================] - 2s 280ms/step - c_loss: -53.4055 - c_wass_loss: -76.8208 - c_gp: 2.3415 - g_loss: -176.1080
# Epoch 38/6000
# 8/8 [==============================] - 2s 293ms/step - c_loss: -56.8186 - c_wass_loss: -80.4932 - c_gp: 2.3675 - g_loss: -177.9610
# Epoch 39/6000
# 8/8 [==============================] - 2s 279ms/step - c_loss: -50.8061 - c_wass_loss: -79.5497 - c_gp: 2.8744 - g_loss: -153.1098
# Epoch 40/6000
# 8/8 [==============================] - 2s 283ms/step - c_loss: -54.1751 - c_wass_loss: -81.0278 - c_gp: 2.6853 - g_loss: -150.9115
# Epoch 41/6000
# 8/8 [==============================] - 2s 282ms/step - c_loss: -54.8559 - c_wass_loss: -81.3294 - c_gp: 2.6474 - g_loss: -238.8059
# Epoch 42/6000
# 8/8 [==============================] - 2s 281ms/step - c_loss: -49.3230 - c_wass_loss: -82.7893 - c_gp: 3.3466 - g_loss: -503.6812
# Epoch 43/6000
# 8/8 [==============================] - 2s 326ms/step - c_loss: -50.0734 - c_wass_loss: -70.1951 - c_gp: 2.0122 - g_loss: -235.7679
# Epoch 44/6000
# 8/8 [==============================] - 2s 281ms/step - c_loss: -46.1790 - c_wass_loss: -82.0488 - c_gp: 3.5870 - g_loss: -185.4669
# Epoch 45/6000
# 8/8 [==============================] - 2s 284ms/step - c_loss: -49.0313 - c_wass_loss: -68.1901 - c_gp: 1.9159 - g_loss: -160.9007
# Epoch 46/6000
# 8/8 [==============================] - 2s 283ms/step - c_loss: -44.7415 - c_wass_loss: -71.3559 - c_gp: 2.6614 - g_loss: -135.8172
# Epoch 47/6000
# 8/8 [==============================] - 2s 282ms/step - c_loss: -48.5117 - c_wass_loss: -66.8850 - c_gp: 1.8373 - g_loss: -110.4444
# Epoch 48/6000
# 8/8 [==============================] - 2s 305ms/step - c_loss: -43.3074 - c_wass_loss: -69.8189 - c_gp: 2.6511 - g_loss: -108.9380
# Epoch 49/6000
# 8/8 [==============================] - 2s 281ms/step - c_loss: -46.8833 - c_wass_loss: -70.0048 - c_gp: 2.3122 - g_loss: -142.6842
# Epoch 50/6000
# 8/8 [==============================] - 2s 283ms/step - c_loss: -48.3132 - c_wass_loss: -66.6970 - c_gp: 1.8384 - g_loss: -157.0748
# Epoch 51/6000
# 8/8 [==============================] - 2s 280ms/step - c_loss: -45.2164 - c_wass_loss: -66.6755 - c_gp: 2.1459 - g_loss: -141.5275
# Epoch 52/6000
# 8/8 [==============================] - 2s 278ms/step - c_loss: -43.8421 - c_wass_loss: -62.3383 - c_gp: 1.8496 - g_loss: -193.0495
# Epoch 53/6000
# 8/8 [==============================] - 2s 282ms/step - c_loss: -44.6658 - c_wass_loss: -68.3718 - c_gp: 2.3706 - g_loss: -371.7785
# Epoch 54/6000
# 8/8 [==============================] - 2s 319ms/step - c_loss: -46.1886 - c_wass_loss: -69.0203 - c_gp: 2.2832 - g_loss: -194.2883
# Epoch 55/6000
# 8/8 [==============================] - 2s 279ms/step - c_loss: -46.7629 - c_wass_loss: -69.8641 - c_gp: 2.3101 - g_loss: -148.9487
# Epoch 56/6000
# 8/8 [==============================] - 2s 311ms/step - c_loss: -43.4013 - c_wass_loss: -74.2016 - c_gp: 3.0800 - g_loss: -108.5580
# Epoch 57/6000
# 8/8 [==============================] - 2s 280ms/step - c_loss: -47.4492 - c_wass_loss: -70.8048 - c_gp: 2.3356 - g_loss: -108.9625
# Epoch 58/6000
# 8/8 [==============================] - 2s 283ms/step - c_loss: -45.6835 - c_wass_loss: -66.7925 - c_gp: 2.1109 - g_loss: -102.7294
# Epoch 59/6000
# 8/8 [==============================] - 2s 311ms/step - c_loss: -45.6096 - c_wass_loss: -72.5698 - c_gp: 2.6960 - g_loss: -261.9648
# Epoch 60/6000
# 8/8 [==============================] - 2s 282ms/step - c_loss: -47.7112 - c_wass_loss: -72.4480 - c_gp: 2.4737 - g_loss: -137.4429
# Epoch 61/6000
# 8/8 [==============================] - 2s 280ms/step - c_loss: -45.4238 - c_wass_loss: -68.5209 - c_gp: 2.3097 - g_loss: -94.6798
# Epoch 62/6000
# 8/8 [==============================] - 2s 283ms/step - c_loss: -30.6718 - c_wass_loss: -77.8656 - c_gp: 4.7194 - g_loss: -165.0555
# Epoch 63/6000
# 8/8 [==============================] - 2s 283ms/step - c_loss: -41.1170 - c_wass_loss: -61.9250 - c_gp: 2.0808 - g_loss: -114.9672
# Epoch 64/6000
# 8/8 [==============================] - 2s 304ms/step - c_loss: -44.4730 - c_wass_loss: -60.7769 - c_gp: 1.6304 - g_loss: -104.1704
# Epoch 65/6000
# 8/8 [==============================] - 2s 279ms/step - c_loss: -44.4343 - c_wass_loss: -63.0861 - c_gp: 1.8652 - g_loss: -142.1067
# Epoch 66/6000
# 8/8 [==============================] - 2s 281ms/step - c_loss: -44.4737 - c_wass_loss: -63.8648 - c_gp: 1.9391 - g_loss: -114.7267
# Epoch 67/6000
# 8/8 [==============================] - 2s 281ms/step - c_loss: -42.1195 - c_wass_loss: -64.5357 - c_gp: 2.2416 - g_loss: -135.0010
# Epoch 68/6000
# 8/8 [==============================] - 2s 279ms/step - c_loss: -44.0530 - c_wass_loss: -64.2146 - c_gp: 2.0162 - g_loss: -109.1780
# Epoch 69/6000
# 8/8 [==============================] - 2s 282ms/step - c_loss: -46.3249 - c_wass_loss: -71.4648 - c_gp: 2.5140 - g_loss: -155.7856
# Epoch 70/6000
# 8/8 [==============================] - 2s 308ms/step - c_loss: -41.7998 - c_wass_loss: -66.1575 - c_gp: 2.4358 - g_loss: -195.7204
# Epoch 71/6000
# 8/8 [==============================] - 2s 284ms/step - c_loss: -41.1690 - c_wass_loss: -55.9462 - c_gp: 1.4777 - g_loss: -145.4649
# Epoch 72/6000
# 8/8 [==============================] - 2s 282ms/step - c_loss: -43.9191 - c_wass_loss: -55.8907 - c_gp: 1.1972 - g_loss: -81.6000
# Epoch 73/6000
# 8/8 [==============================] - 2s 284ms/step - c_loss: -44.6697 - c_wass_loss: -64.9195 - c_gp: 2.0250 - g_loss: -85.9098
# Epoch 74/6000
# 8/8 [==============================] - 2s 281ms/step - c_loss: -48.0546 - c_wass_loss: -68.8118 - c_gp: 2.0757 - g_loss: -148.7469
# Epoch 75/6000
# 8/8 [==============================] - 2s 308ms/step - c_loss: -39.0083 - c_wass_loss: -70.4025 - c_gp: 3.1394 - g_loss: -192.4204
# Epoch 76/6000
# 8/8 [==============================] - 2s 283ms/step - c_loss: -43.9570 - c_wass_loss: -62.1035 - c_gp: 1.8147 - g_loss: -217.0480
# Epoch 77/6000
# 8/8 [==============================] - 2s 282ms/step - c_loss: -44.7706 - c_wass_loss: -58.1836 - c_gp: 1.3413 - g_loss: -125.0110
# Epoch 78/6000
# 8/8 [==============================] - 2s 282ms/step - c_loss: -42.2615 - c_wass_loss: -60.8902 - c_gp: 1.8629 - g_loss: -131.7276
# Epoch 79/6000
# 8/8 [==============================] - 2s 279ms/step - c_loss: -42.9724 - c_wass_loss: -68.2498 - c_gp: 2.5277 - g_loss: -158.7110
# Epoch 80/6000
# 8/8 [==============================] - 2s 308ms/step - c_loss: -43.7307 - c_wass_loss: -62.8602 - c_gp: 1.9130 - g_loss: -95.4798
# Epoch 81/6000
# 8/8 [==============================] - 2s 282ms/step - c_loss: -41.6166 - c_wass_loss: -58.1764 - c_gp: 1.6560 - g_loss: -233.6127
# Epoch 82/6000
# 8/8 [==============================] - 2s 278ms/step - c_loss: -43.8092 - c_wass_loss: -66.6842 - c_gp: 2.2875 - g_loss: -133.8813
# Epoch 83/6000
# 8/8 [==============================] - 2s 280ms/step - c_loss: -41.3758 - c_wass_loss: -57.6685 - c_gp: 1.6293 - g_loss: -118.2822
# Epoch 84/6000
# 8/8 [==============================] - 2s 282ms/step - c_loss: -36.5499 - c_wass_loss: -56.9183 - c_gp: 2.0368 - g_loss: -103.8868
# Epoch 85/6000
# 8/8 [==============================] - 2s 285ms/step - c_loss: -38.5947 - c_wass_loss: -57.3129 - c_gp: 1.8718 - g_loss: -73.0307
# Epoch 86/6000
# 8/8 [==============================] - 2s 303ms/step - c_loss: -39.6550 - c_wass_loss: -59.5475 - c_gp: 1.9892 - g_loss: -130.2670
# Epoch 87/6000
# 8/8 [==============================] - 2s 280ms/step - c_loss: -36.9805 - c_wass_loss: -52.1874 - c_gp: 1.5207 - g_loss: -103.0191
# Epoch 88/6000
# 8/8 [==============================] - 2s 283ms/step - c_loss: -41.4789 - c_wass_loss: -61.0997 - c_gp: 1.9621 - g_loss: -79.3801
# Epoch 89/6000
# 8/8 [==============================] - 2s 281ms/step - c_loss: -40.4454 - c_wass_loss: -61.6313 - c_gp: 2.1186 - g_loss: -266.4113
# Epoch 90/6000
# 8/8 [==============================] - 2s 281ms/step - c_loss: -43.1285 - c_wass_loss: -63.3012 - c_gp: 2.0173 - g_loss: -87.5716
# Epoch 91/6000
# 8/8 [==============================] - 2s 322ms/step - c_loss: -37.3649 - c_wass_loss: -53.9398 - c_gp: 1.6575 - g_loss: -95.7054
# Epoch 92/6000
# 8/8 [==============================] - 2s 282ms/step - c_loss: -38.8689 - c_wass_loss: -63.9131 - c_gp: 2.5044 - g_loss: -77.6150
# Epoch 93/6000
# 8/8 [==============================] - 2s 280ms/step - c_loss: -36.9836 - c_wass_loss: -57.1326 - c_gp: 2.0149 - g_loss: -154.6891
# Epoch 94/6000
# 8/8 [==============================] - 2s 284ms/step - c_loss: -39.3066 - c_wass_loss: -60.1634 - c_gp: 2.0857 - g_loss: -106.8441
# Epoch 95/6000
# 8/8 [==============================] - 2s 280ms/step - c_loss: -38.4779 - c_wass_loss: -59.5638 - c_gp: 2.1086 - g_loss: -94.3015
# Epoch 96/6000
# 8/8 [==============================] - 2s 279ms/step - c_loss: -36.9360 - c_wass_loss: -57.9228 - c_gp: 2.0987 - g_loss: -117.8169
# Epoch 97/6000
# 8/8 [==============================] - 2s 283ms/step - c_loss: -38.6014 - c_wass_loss: -54.4137 - c_gp: 1.5812 - g_loss: -102.0511
# Epoch 98/6000
# 8/8 [==============================] - 2s 282ms/step - c_loss: -35.6599 - c_wass_loss: -48.2903 - c_gp: 1.2630 - g_loss: -79.2505
# Epoch 99/6000
# 8/8 [==============================] - 2s 282ms/step - c_loss: -39.6213 - c_wass_loss: -57.0041 - c_gp: 1.7383 - g_loss: -85.0087
# Epoch 100/6000
# 8/8 [==============================] - 2s 281ms/step - c_loss: -34.3983 - c_wass_loss: -63.4476 - c_gp: 2.9049 - g_loss: -62.7702
# Epoch 101/6000
# 8/8 [==============================] - 2s 281ms/step - c_loss: -38.2267 - c_wass_loss: -54.1170 - c_gp: 1.5890 - g_loss: -92.7968
# Epoch 102/6000
# 8/8 [==============================] - 2s 305ms/step - c_loss: -38.9837 - c_wass_loss: -58.4585 - c_gp: 1.9475 - g_loss: -136.8268
# Epoch 103/6000
# 8/8 [==============================] - 2s 308ms/step - c_loss: -38.0373 - c_wass_loss: -54.6627 - c_gp: 1.6625 - g_loss: -112.3026
# Epoch 104/6000
# 8/8 [==============================] - 2s 280ms/step - c_loss: -39.1275 - c_wass_loss: -60.2084 - c_gp: 2.1081 - g_loss: -101.3522
# Epoch 105/6000
# 8/8 [==============================] - 2s 280ms/step - c_loss: -38.8586 - c_wass_loss: -54.3713 - c_gp: 1.5513 - g_loss: -124.5192
# Epoch 106/6000
# 8/8 [==============================] - 2s 281ms/step - c_loss: -36.5241 - c_wass_loss: -67.5187 - c_gp: 3.0995 - g_loss: -48.7995
# Epoch 107/6000
# 8/8 [==============================] - 2s 305ms/step - c_loss: -38.2429 - c_wass_loss: -59.9388 - c_gp: 2.1696 - g_loss: -161.1141
# Epoch 108/6000
# 8/8 [==============================] - 2s 281ms/step - c_loss: -36.0440 - c_wass_loss: -55.1949 - c_gp: 1.9151 - g_loss: -109.1594
# Epoch 109/6000
# 8/8 [==============================] - 2s 283ms/step - c_loss: -38.8929 - c_wass_loss: -55.0641 - c_gp: 1.6171 - g_loss: -96.8639
# Epoch 110/6000
# 8/8 [==============================] - 2s 284ms/step - c_loss: -38.9414 - c_wass_loss: -59.7039 - c_gp: 2.0763 - g_loss: -79.5684
# Epoch 111/6000
# 8/8 [==============================] - 2s 281ms/step - c_loss: -40.5854 - c_wass_loss: -56.2704 - c_gp: 1.5685 - g_loss: -92.5813
# Epoch 112/6000
# 8/8 [==============================] - 2s 280ms/step - c_loss: -42.4474 - c_wass_loss: -57.6098 - c_gp: 1.5162 - g_loss: -161.9070
# Epoch 113/6000
# 8/8 [==============================] - 2s 308ms/step - c_loss: -41.1484 - c_wass_loss: -63.2551 - c_gp: 2.2107 - g_loss: -91.3609
# Epoch 114/6000
# 8/8 [==============================] - 2s 279ms/step - c_loss: -39.5909 - c_wass_loss: -55.2984 - c_gp: 1.5707 - g_loss: -161.3557
# Epoch 115/6000
# 8/8 [==============================] - 2s 283ms/step - c_loss: -37.9024 - c_wass_loss: -57.1155 - c_gp: 1.9213 - g_loss: -42.2614
# Epoch 116/6000
# 8/8 [==============================] - 2s 279ms/step - c_loss: -35.5351 - c_wass_loss: -59.0456 - c_gp: 2.3510 - g_loss: -113.7285
# Epoch 117/6000
# 8/8 [==============================] - 2s 282ms/step - c_loss: -38.0719 - c_wass_loss: -59.1999 - c_gp: 2.1128 - g_loss: -98.2101
# Epoch 118/6000
# 8/8 [==============================] - 2s 281ms/step - c_loss: -38.1502 - c_wass_loss: -59.0644 - c_gp: 2.0914 - g_loss: -221.4275
# Epoch 119/6000
# 8/8 [==============================] - 2s 279ms/step - c_loss: -36.8910 - c_wass_loss: -53.2332 - c_gp: 1.6342 - g_loss: -54.4897
# Epoch 120/6000
# 8/8 [==============================] - 2s 279ms/step - c_loss: -38.0145 - c_wass_loss: -53.4740 - c_gp: 1.5459 - g_loss: -107.9531
# Epoch 121/6000
# 8/8 [==============================] - 2s 280ms/step - c_loss: -38.7887 - c_wass_loss: -51.7916 - c_gp: 1.3003 - g_loss: -103.9861
# Epoch 122/6000
# 8/8 [==============================] - 2s 281ms/step - c_loss: -36.6150 - c_wass_loss: -53.9790 - c_gp: 1.7364 - g_loss: -79.6337
# Epoch 123/6000
# 8/8 [==============================] - 2s 327ms/step - c_loss: -34.9754 - c_wass_loss: -57.0934 - c_gp: 2.2118 - g_loss: -102.2731
# Epoch 124/6000
# 8/8 [==============================] - 2s 281ms/step - c_loss: -41.3420 - c_wass_loss: -58.7771 - c_gp: 1.7435 - g_loss: -140.4032
# Epoch 125/6000
# 8/8 [==============================] - 2s 281ms/step - c_loss: -36.1154 - c_wass_loss: -54.1498 - c_gp: 1.8034 - g_loss: -51.9072
# Epoch 126/6000
# 8/8 [==============================] - 2s 281ms/step - c_loss: -40.3697 - c_wass_loss: -58.8579 - c_gp: 1.8488 - g_loss: -70.3831
# Epoch 127/6000
# 8/8 [==============================] - 2s 309ms/step - c_loss: -29.8989 - c_wass_loss: -62.2321 - c_gp: 3.2333 - g_loss: -47.5327
# Epoch 128/6000
# 8/8 [==============================] - 2s 289ms/step - c_loss: -33.1458 - c_wass_loss: -58.5616 - c_gp: 2.5416 - g_loss: -117.5869
# Epoch 129/6000
# 8/8 [==============================] - 2s 279ms/step - c_loss: -35.8411 - c_wass_loss: -48.3409 - c_gp: 1.2500 - g_loss: -91.7757
# Epoch 130/6000
# 8/8 [==============================] - 2s 280ms/step - c_loss: -31.5951 - c_wass_loss: -52.4303 - c_gp: 2.0835 - g_loss: -61.3273
# Epoch 131/6000
# 8/8 [==============================] - 2s 282ms/step - c_loss: -32.0611 - c_wass_loss: -48.1543 - c_gp: 1.6093 - g_loss: -143.9586
# Epoch 132/6000
# 8/8 [==============================] - 2s 278ms/step - c_loss: -30.4333 - c_wass_loss: -48.7634 - c_gp: 1.8330 - g_loss: -81.3213
# Epoch 133/6000
# 8/8 [==============================] - 2s 277ms/step - c_loss: -33.4225 - c_wass_loss: -47.9320 - c_gp: 1.4509 - g_loss: -96.7514
# Epoch 134/6000
# 8/8 [==============================] - 2s 310ms/step - c_loss: -32.7467 - c_wass_loss: -43.6176 - c_gp: 1.0871 - g_loss: -85.0720
# Epoch 135/6000
# 8/8 [==============================] - 2s 280ms/step - c_loss: -31.2379 - c_wass_loss: -42.2190 - c_gp: 1.0981 - g_loss: -121.5546
# Epoch 136/6000
# 8/8 [==============================] - 2s 276ms/step - c_loss: -31.8672 - c_wass_loss: -50.4328 - c_gp: 1.8566 - g_loss: -82.8563
# Epoch 137/6000
# 8/8 [==============================] - 2s 279ms/step - c_loss: -29.8825 - c_wass_loss: -47.2801 - c_gp: 1.7398 - g_loss: -70.9022
# Epoch 138/6000
# 8/8 [==============================] - 2s 281ms/step - c_loss: -32.0789 - c_wass_loss: -48.8478 - c_gp: 1.6769 - g_loss: -97.5563
# Epoch 139/6000
# 8/8 [==============================] - 2s 322ms/step - c_loss: -35.2880 - c_wass_loss: -44.6466 - c_gp: 0.9359 - g_loss: -80.1314
# Epoch 140/6000
# 8/8 [==============================] - 2s 281ms/step - c_loss: -34.2469 - c_wass_loss: -46.2115 - c_gp: 1.1965 - g_loss: -66.2096
# Epoch 141/6000
# 8/8 [==============================] - 2s 280ms/step - c_loss: -25.3328 - c_wass_loss: -51.8945 - c_gp: 2.6562 - g_loss: -122.2365
# Epoch 142/6000
# 8/8 [==============================] - 2s 281ms/step - c_loss: -34.3663 - c_wass_loss: -48.7028 - c_gp: 1.4337 - g_loss: -61.7979
# Epoch 143/6000
# 8/8 [==============================] - 2s 280ms/step - c_loss: -36.9536 - c_wass_loss: -47.5811 - c_gp: 1.0628 - g_loss: -120.1634
# Epoch 144/6000
# 8/8 [==============================] - 2s 324ms/step - c_loss: -33.4840 - c_wass_loss: -51.0100 - c_gp: 1.7526 - g_loss: -75.1360
# Epoch 145/6000
# 8/8 [==============================] - 2s 281ms/step - c_loss: -35.1666 - c_wass_loss: -51.2176 - c_gp: 1.6051 - g_loss: -31.8835
# Epoch 146/6000
# 8/8 [==============================] - 2s 279ms/step - c_loss: -35.1513 - c_wass_loss: -45.3996 - c_gp: 1.0248 - g_loss: -74.1995
# Epoch 147/6000
# 8/8 [==============================] - 2s 280ms/step - c_loss: -31.5263 - c_wass_loss: -45.1788 - c_gp: 1.3653 - g_loss: -99.0507
# Epoch 148/6000
# 8/8 [==============================] - 2s 281ms/step - c_loss: -30.3917 - c_wass_loss: -41.0524 - c_gp: 1.0661 - g_loss: -75.8700
# Epoch 149/6000
# 8/8 [==============================] - 2s 280ms/step - c_loss: -30.1078 - c_wass_loss: -46.3810 - c_gp: 1.6273 - g_loss: -28.2691
# Epoch 150/6000
# 8/8 [==============================] - 2s 279ms/step - c_loss: -31.7574 - c_wass_loss: -47.4871 - c_gp: 1.5730 - g_loss: -53.8460
# Epoch 151/6000
# 8/8 [==============================] - 2s 310ms/step - c_loss: -32.0673 - c_wass_loss: -44.6672 - c_gp: 1.2600 - g_loss: -51.3410
# Epoch 152/6000
# 8/8 [==============================] - 2s 281ms/step - c_loss: -30.9040 - c_wass_loss: -49.1114 - c_gp: 1.8207 - g_loss: -59.7329
# Epoch 153/6000
# 8/8 [==============================] - 2s 281ms/step - c_loss: -33.3423 - c_wass_loss: -43.9149 - c_gp: 1.0573 - g_loss: -73.3240
# Epoch 154/6000
# 8/8 [==============================] - 2s 282ms/step - c_loss: -31.7627 - c_wass_loss: -51.4761 - c_gp: 1.9713 - g_loss: -55.6125
# Epoch 155/6000
# 8/8 [==============================] - 2s 326ms/step - c_loss: -33.7666 - c_wass_loss: -45.5792 - c_gp: 1.1813 - g_loss: -170.1785
# Epoch 156/6000
# 8/8 [==============================] - 2s 279ms/step - c_loss: -32.8444 - c_wass_loss: -45.8558 - c_gp: 1.3011 - g_loss: -71.6458
# Epoch 157/6000
# 8/8 [==============================] - 2s 282ms/step - c_loss: -33.3213 - c_wass_loss: -48.0138 - c_gp: 1.4693 - g_loss: -77.5809
# Epoch 158/6000
# 8/8 [==============================] - 2s 282ms/step - c_loss: -33.7984 - c_wass_loss: -45.2514 - c_gp: 1.1453 - g_loss: -53.6083
# Epoch 159/6000
# 8/8 [==============================] - 2s 280ms/step - c_loss: -32.9169 - c_wass_loss: -40.5023 - c_gp: 0.7585 - g_loss: -32.3979
# Epoch 160/6000
# 8/8 [==============================] - 2s 317ms/step - c_loss: -29.9519 - c_wass_loss: -53.2948 - c_gp: 2.3343 - g_loss: -41.8756
# Epoch 161/6000
# 8/8 [==============================] - 2s 281ms/step - c_loss: -35.1230 - c_wass_loss: -46.3846 - c_gp: 1.1262 - g_loss: -97.3165
# Epoch 162/6000
# 8/8 [==============================] - 2s 281ms/step - c_loss: -35.5143 - c_wass_loss: -50.0162 - c_gp: 1.4502 - g_loss: -33.8328
# Epoch 163/6000
# 8/8 [==============================] - 2s 279ms/step - c_loss: -32.0450 - c_wass_loss: -47.2092 - c_gp: 1.5164 - g_loss: -47.4097
# Epoch 164/6000
# 8/8 [==============================] - 2s 285ms/step - c_loss: -37.9003 - c_wass_loss: -50.1367 - c_gp: 1.2236 - g_loss: -95.1510
# Epoch 165/6000
# 8/8 [==============================] - 2s 326ms/step - c_loss: -33.6302 - c_wass_loss: -49.5380 - c_gp: 1.5908 - g_loss: -79.6885
# Epoch 166/6000
# 8/8 [==============================] - 2s 283ms/step - c_loss: -31.5659 - c_wass_loss: -46.4322 - c_gp: 1.4866 - g_loss: -133.6754
# Epoch 167/6000
# 8/8 [==============================] - 2s 283ms/step - c_loss: -31.0036 - c_wass_loss: -48.9136 - c_gp: 1.7910 - g_loss: -50.9516
# Epoch 168/6000
# 8/8 [==============================] - 2s 281ms/step - c_loss: -34.4012 - c_wass_loss: -44.1057 - c_gp: 0.9705 - g_loss: -91.7436
# Epoch 169/6000
# 8/8 [==============================] - 2s 279ms/step - c_loss: -30.1901 - c_wass_loss: -44.8986 - c_gp: 1.4708 - g_loss: -171.7234
# Epoch 170/6000
# 8/8 [==============================] - 2s 280ms/step - c_loss: -34.2112 - c_wass_loss: -54.3602 - c_gp: 2.0149 - g_loss: -24.2218
# Epoch 171/6000
# 8/8 [==============================] - 2s 282ms/step - c_loss: -32.3454 - c_wass_loss: -43.2718 - c_gp: 1.0926 - g_loss: -175.5892
# Epoch 172/6000
# 8/8 [==============================] - 2s 281ms/step - c_loss: -34.5722 - c_wass_loss: -51.0422 - c_gp: 1.6470 - g_loss: -121.9306
# Epoch 173/6000
# 8/8 [==============================] - 2s 281ms/step - c_loss: -33.5826 - c_wass_loss: -45.0362 - c_gp: 1.1454 - g_loss: -257.7314
# Epoch 174/6000
# 8/8 [==============================] - 2s 313ms/step - c_loss: -29.8364 - c_wass_loss: -60.5263 - c_gp: 3.0690 - g_loss: -127.9286
# Epoch 175/6000
# 8/8 [==============================] - 2s 288ms/step - c_loss: -33.9865 - c_wass_loss: -45.7747 - c_gp: 1.1788 - g_loss: 1.5703
# Epoch 176/6000
# 8/8 [==============================] - 3s 330ms/step - c_loss: -33.3743 - c_wass_loss: -45.3309 - c_gp: 1.1957 - g_loss: -60.0217
# Epoch 177/6000
# 8/8 [==============================] - 2s 286ms/step - c_loss: -33.2797 - c_wass_loss: -44.6091 - c_gp: 1.1329 - g_loss: -110.9155
# Epoch 178/6000
# 8/8 [==============================] - 2s 283ms/step - c_loss: -28.6174 - c_wass_loss: -44.6561 - c_gp: 1.6039 - g_loss: -42.5549
# Epoch 179/6000
# 8/8 [==============================] - 2s 288ms/step - c_loss: -34.4236 - c_wass_loss: -55.3869 - c_gp: 2.0963 - g_loss: -67.0888
# Epoch 180/6000
# 8/8 [==============================] - 2s 283ms/step - c_loss: -22.3504 - c_wass_loss: -51.9399 - c_gp: 2.9590 - g_loss: -116.1146
# Epoch 181/6000
# 8/8 [==============================] - 3s 332ms/step - c_loss: -29.5493 - c_wass_loss: -41.6512 - c_gp: 1.2102 - g_loss: -29.1721
# Epoch 182/6000
# 8/8 [==============================] - 2s 282ms/step - c_loss: -31.3655 - c_wass_loss: -45.4291 - c_gp: 1.4064 - g_loss: -135.0972
# Epoch 183/6000
# 8/8 [==============================] - 2s 281ms/step - c_loss: -30.9713 - c_wass_loss: -44.7138 - c_gp: 1.3742 - g_loss: -19.8785
# Epoch 184/6000
# 8/8 [==============================] - 2s 283ms/step - c_loss: -30.2991 - c_wass_loss: -47.0725 - c_gp: 1.6773 - g_loss: -60.7629
# Epoch 185/6000
# 8/8 [==============================] - 2s 283ms/step - c_loss: -30.8702 - c_wass_loss: -47.0663 - c_gp: 1.6196 - g_loss: -114.8656
# Epoch 186/6000
# 8/8 [==============================] - 2s 316ms/step - c_loss: -28.8051 - c_wass_loss: -45.1910 - c_gp: 1.6386 - g_loss: -69.7144
# Epoch 187/6000
# 8/8 [==============================] - 2s 283ms/step - c_loss: -30.9631 - c_wass_loss: -45.0269 - c_gp: 1.4064 - g_loss: -47.6690
# Epoch 188/6000
# 8/8 [==============================] - 2s 283ms/step - c_loss: -28.1088 - c_wass_loss: -38.9049 - c_gp: 1.0796 - g_loss: -0.8713
# Epoch 189/6000
# 8/8 [==============================] - 2s 282ms/step - c_loss: -30.5715 - c_wass_loss: -42.9401 - c_gp: 1.2369 - g_loss: -57.2060
# Epoch 190/6000
# 8/8 [==============================] - 2s 283ms/step - c_loss: -31.3736 - c_wass_loss: -48.5493 - c_gp: 1.7176 - g_loss: -124.2558
# Epoch 191/6000
# 8/8 [==============================] - 2s 287ms/step - c_loss: -32.2338 - c_wass_loss: -44.0684 - c_gp: 1.1835 - g_loss: -63.9043
# Epoch 192/6000
# 8/8 [==============================] - 2s 284ms/step - c_loss: -30.3841 - c_wass_loss: -45.4984 - c_gp: 1.5114 - g_loss: -88.2994
# Epoch 193/6000
# 8/8 [==============================] - 2s 282ms/step - c_loss: -32.6063 - c_wass_loss: -45.6963 - c_gp: 1.3090 - g_loss: -121.5149
# Epoch 194/6000
# 8/8 [==============================] - 2s 279ms/step - c_loss: -31.4629 - c_wass_loss: -42.7289 - c_gp: 1.1266 - g_loss: -29.1492
# Epoch 195/6000
# 8/8 [==============================] - 2s 285ms/step - c_loss: -33.2645 - c_wass_loss: -44.8209 - c_gp: 1.1556 - g_loss: -113.3546
# Epoch 196/6000
# 8/8 [==============================] - 2s 284ms/step - c_loss: -27.8880 - c_wass_loss: -51.0785 - c_gp: 2.3191 - g_loss: -50.7763
# Epoch 197/6000
# 8/8 [==============================] - 3s 331ms/step - c_loss: -30.0390 - c_wass_loss: -40.0510 - c_gp: 1.0012 - g_loss: -176.8741
# Epoch 198/6000
# 8/8 [==============================] - 2s 311ms/step - c_loss: -29.9369 - c_wass_loss: -45.2615 - c_gp: 1.5325 - g_loss: -178.9123
# Epoch 199/6000
# 8/8 [==============================] - 2s 282ms/step - c_loss: -33.3295 - c_wass_loss: -48.5765 - c_gp: 1.5247 - g_loss: -87.8430
# Epoch 200/6000
# 8/8 [==============================] - 2s 283ms/step - c_loss: -30.8337 - c_wass_loss: -41.2804 - c_gp: 1.0447 - g_loss: -23.4117
# Epoch 201/6000
# 8/8 [==============================] - 2s 280ms/step - c_loss: -29.7988 - c_wass_loss: -42.5391 - c_gp: 1.2740 - g_loss: -106.8045
# Epoch 202/6000
# 8/8 [==============================] - 2s 317ms/step - c_loss: -28.2237 - c_wass_loss: -43.8350 - c_gp: 1.5611 - g_loss: -108.4426
# Epoch 203/6000
# 8/8 [==============================] - 2s 283ms/step - c_loss: -29.4695 - c_wass_loss: -41.1471 - c_gp: 1.1678 - g_loss: -46.9633
# Epoch 204/6000
# 8/8 [==============================] - 2s 281ms/step - c_loss: -29.2552 - c_wass_loss: -44.8581 - c_gp: 1.5603 - g_loss: -25.2389
# Epoch 205/6000
# 8/8 [==============================] - 2s 282ms/step - c_loss: -28.4075 - c_wass_loss: -39.3224 - c_gp: 1.0915 - g_loss: -109.1217
# Epoch 206/6000
# 8/8 [==============================] - 2s 285ms/step - c_loss: -31.1549 - c_wass_loss: -47.7595 - c_gp: 1.6605 - g_loss: -33.4262
# Epoch 207/6000
# 8/8 [==============================] - 2s 314ms/step - c_loss: -27.8871 - c_wass_loss: -44.6023 - c_gp: 1.6715 - g_loss: -56.1786
# Epoch 208/6000
# 8/8 [==============================] - 2s 285ms/step - c_loss: -30.6725 - c_wass_loss: -47.2076 - c_gp: 1.6535 - g_loss: -62.5139
# Epoch 209/6000
# 8/8 [==============================] - 2s 283ms/step - c_loss: -31.8094 - c_wass_loss: -45.0351 - c_gp: 1.3226 - g_loss: 28.5306
# Epoch 210/6000
# 8/8 [==============================] - 2s 279ms/step - c_loss: -28.6292 - c_wass_loss: -45.1881 - c_gp: 1.6559 - g_loss: -29.4611
# Epoch 211/6000
# 8/8 [==============================] - 2s 285ms/step - c_loss: -29.7687 - c_wass_loss: -39.5789 - c_gp: 0.9810 - g_loss: -11.4779
# Epoch 212/6000
# 8/8 [==============================] - 2s 298ms/step - c_loss: -30.3008 - c_wass_loss: -40.6522 - c_gp: 1.0351 - g_loss: -59.4679
# Epoch 213/6000
# 8/8 [==============================] - 2s 279ms/step - c_loss: -28.7102 - c_wass_loss: -51.4510 - c_gp: 2.2741 - g_loss: -99.6488
# Epoch 214/6000
# 8/8 [==============================] - 2s 281ms/step - c_loss: -31.2658 - c_wass_loss: -41.3035 - c_gp: 1.0038 - g_loss: 17.6186
# Epoch 215/6000
# 8/8 [==============================] - 2s 279ms/step - c_loss: -30.7063 - c_wass_loss: -41.1633 - c_gp: 1.0457 - g_loss: -76.3461
# Epoch 216/6000
# 8/8 [==============================] - 2s 284ms/step - c_loss: -28.2610 - c_wass_loss: -39.2217 - c_gp: 1.0961 - g_loss: -90.2501
# Epoch 217/6000
# 8/8 [==============================] - 2s 281ms/step - c_loss: -28.5129 - c_wass_loss: -35.8087 - c_gp: 0.7296 - g_loss: -129.5226
# Epoch 218/6000
# 8/8 [==============================] - 2s 321ms/step - c_loss: -25.5010 - c_wass_loss: -45.4407 - c_gp: 1.9940 - g_loss: 13.8533
# Epoch 219/6000
# 8/8 [==============================] - 2s 279ms/step - c_loss: -28.6715 - c_wass_loss: -37.2709 - c_gp: 0.8599 - g_loss: -7.9868
# Epoch 220/6000
# 8/8 [==============================] - 2s 284ms/step - c_loss: -27.6137 - c_wass_loss: -40.6726 - c_gp: 1.3059 - g_loss: -51.3409
# Epoch 221/6000
# 8/8 [==============================] - 2s 283ms/step - c_loss: -26.9174 - c_wass_loss: -38.4186 - c_gp: 1.1501 - g_loss: -60.9612
# Epoch 222/6000
# 8/8 [==============================] - 2s 311ms/step - c_loss: -28.3289 - c_wass_loss: -40.7738 - c_gp: 1.2445 - g_loss: -32.1419
# Epoch 223/6000
# 8/8 [==============================] - 2s 313ms/step - c_loss: -27.3527 - c_wass_loss: -47.6268 - c_gp: 2.0274 - g_loss: -6.6077
# Epoch 224/6000
# 8/8 [==============================] - 2s 280ms/step - c_loss: -29.1702 - c_wass_loss: -49.4152 - c_gp: 2.0245 - g_loss: -123.1488
# Epoch 225/6000
# 8/8 [==============================] - 2s 283ms/step - c_loss: -29.5341 - c_wass_loss: -38.5819 - c_gp: 0.9048 - g_loss: -125.4583
# Epoch 226/6000
# 8/8 [==============================] - 2s 282ms/step - c_loss: -29.5406 - c_wass_loss: -43.5563 - c_gp: 1.4016 - g_loss: -41.8206
# Epoch 227/6000
# 8/8 [==============================] - 2s 283ms/step - c_loss: -31.0018 - c_wass_loss: -39.8306 - c_gp: 0.8829 - g_loss: 8.6761
# Epoch 228/6000
# 8/8 [==============================] - 2s 316ms/step - c_loss: -28.2051 - c_wass_loss: -37.8501 - c_gp: 0.9645 - g_loss: -47.8148
# Epoch 229/6000
# 8/8 [==============================] - 2s 284ms/step - c_loss: -27.9267 - c_wass_loss: -35.0157 - c_gp: 0.7089 - g_loss: -46.3590
# Epoch 230/6000
# 8/8 [==============================] - 2s 287ms/step - c_loss: -30.1064 - c_wass_loss: -44.2047 - c_gp: 1.4098 - g_loss: -37.1169
# Epoch 231/6000
# 8/8 [==============================] - 2s 281ms/step - c_loss: -15.8361 - c_wass_loss: -47.2444 - c_gp: 3.1408 - g_loss: -97.4788
# Epoch 232/6000
# 8/8 [==============================] - 2s 283ms/step - c_loss: -30.5389 - c_wass_loss: -39.9852 - c_gp: 0.9446 - g_loss: -40.9968
# Epoch 233/6000
# 8/8 [==============================] - 3s 330ms/step - c_loss: -28.6951 - c_wass_loss: -37.4152 - c_gp: 0.8720 - g_loss: -77.6110
# Epoch 234/6000
# 8/8 [==============================] - 2s 283ms/step - c_loss: -25.5015 - c_wass_loss: -45.4845 - c_gp: 1.9983 - g_loss: -81.4815
# Epoch 235/6000
# 8/8 [==============================] - 2s 281ms/step - c_loss: -31.3407 - c_wass_loss: -41.9805 - c_gp: 1.0640 - g_loss: -3.1189
# Epoch 236/6000
# 8/8 [==============================] - 2s 280ms/step - c_loss: -29.4698 - c_wass_loss: -38.8050 - c_gp: 0.9335 - g_loss: 18.3779
# Epoch 237/6000
# 8/8 [==============================] - 2s 280ms/step - c_loss: -27.5584 - c_wass_loss: -42.7778 - c_gp: 1.5219 - g_loss: -34.6537
# Epoch 238/6000
# 8/8 [==============================] - 2s 301ms/step - c_loss: -25.7752 - c_wass_loss: -43.0805 - c_gp: 1.7305 - g_loss: -93.3527
# Epoch 239/6000
# 8/8 [==============================] - 2s 282ms/step - c_loss: -28.3886 - c_wass_loss: -37.9307 - c_gp: 0.9542 - g_loss: -4.8331
# Epoch 240/6000
# 8/8 [==============================] - 2s 282ms/step - c_loss: -27.1652 - c_wass_loss: -41.4375 - c_gp: 1.4272 - g_loss: -19.3612
# Epoch 241/6000
# 8/8 [==============================] - 2s 282ms/step - c_loss: -26.6476 - c_wass_loss: -47.0326 - c_gp: 2.0385 - g_loss: -118.2586
# Epoch 242/6000
# 8/8 [==============================] - 2s 281ms/step - c_loss: -30.2167 - c_wass_loss: -46.4032 - c_gp: 1.6187 - g_loss: -1.4272
# Epoch 243/6000
# 8/8 [==============================] - 2s 286ms/step - c_loss: -26.5257 - c_wass_loss: -48.5779 - c_gp: 2.2052 - g_loss: 29.1883
# Epoch 244/6000
# 8/8 [==============================] - 3s 337ms/step - c_loss: -26.7417 - c_wass_loss: -42.3786 - c_gp: 1.5637 - g_loss: -57.8947
# Epoch 245/6000
# 8/8 [==============================] - 2s 293ms/step - c_loss: -25.3201 - c_wass_loss: -35.5573 - c_gp: 1.0237 - g_loss: -39.5181
# Epoch 246/6000
# 8/8 [==============================] - 2s 283ms/step - c_loss: -28.7795 - c_wass_loss: -37.9219 - c_gp: 0.9142 - g_loss: 16.8150
# Epoch 247/6000
# 8/8 [==============================] - 2s 311ms/step - c_loss: -27.5796 - c_wass_loss: -41.4076 - c_gp: 1.3828 - g_loss: 35.0485
# Epoch 248/6000
# 8/8 [==============================] - 2s 286ms/step - c_loss: -29.8934 - c_wass_loss: -41.0466 - c_gp: 1.1153 - g_loss: -49.9421
# Epoch 249/6000
# 8/8 [==============================] - 2s 283ms/step - c_loss: -29.4121 - c_wass_loss: -41.8809 - c_gp: 1.2469 - g_loss: 20.6212
# Epoch 250/6000
# 8/8 [==============================] - 2s 283ms/step - c_loss: -21.0669 - c_wass_loss: -48.7783 - c_gp: 2.7711 - g_loss: -28.2659
# Epoch 251/6000
# 8/8 [==============================] - 2s 283ms/step - c_loss: -12.1054 - c_wass_loss: -49.2412 - c_gp: 3.7136 - g_loss: -28.6379
# Epoch 252/6000
# 8/8 [==============================] - 2s 277ms/step - c_loss: -28.0390 - c_wass_loss: -42.9444 - c_gp: 1.4905 - g_loss: 39.9620
# Epoch 253/6000
# 8/8 [==============================] - 2s 282ms/step - c_loss: -12.3069 - c_wass_loss: -53.4842 - c_gp: 4.1177 - g_loss: 10.3622
# Epoch 254/6000
# 8/8 [==============================] - 2s 316ms/step - c_loss: -23.1898 - c_wass_loss: -43.9204 - c_gp: 2.0731 - g_loss: 61.9538
# Epoch 255/6000
# 8/8 [==============================] - 2s 282ms/step - c_loss: -30.1312 - c_wass_loss: -40.7371 - c_gp: 1.0606 - g_loss: -88.8271
# Epoch 256/6000
# 8/8 [==============================] - 2s 279ms/step - c_loss: -29.0155 - c_wass_loss: -39.7488 - c_gp: 1.0733 - g_loss: 37.5579
# Epoch 257/6000
# 8/8 [==============================] - 2s 282ms/step - c_loss: -28.8450 - c_wass_loss: -37.8107 - c_gp: 0.8966 - g_loss: 7.3018
# Epoch 258/6000
# 8/8 [==============================] - 2s 281ms/step - c_loss: -29.6344 - c_wass_loss: -40.0728 - c_gp: 1.0438 - g_loss: 3.9993
# Epoch 259/6000
# 8/8 [==============================] - 3s 331ms/step - c_loss: -29.5840 - c_wass_loss: -40.4357 - c_gp: 1.0852 - g_loss: -30.9765
# Epoch 260/6000
# 8/8 [==============================] - 2s 279ms/step - c_loss: -24.0729 - c_wass_loss: -47.3337 - c_gp: 2.3261 - g_loss: -105.1059
# Epoch 261/6000
# 8/8 [==============================] - 2s 282ms/step - c_loss: -28.3020 - c_wass_loss: -41.9521 - c_gp: 1.3650 - g_loss: 11.0916
# Epoch 262/6000
# 8/8 [==============================] - 2s 279ms/step - c_loss: -29.6374 - c_wass_loss: -42.3493 - c_gp: 1.2712 - g_loss: 44.1671
# Epoch 263/6000
# 8/8 [==============================] - 2s 281ms/step - c_loss: -27.0507 - c_wass_loss: -39.6755 - c_gp: 1.2625 - g_loss: 4.1578
# Epoch 264/6000
# 8/8 [==============================] - 2s 318ms/step - c_loss: -28.8503 - c_wass_loss: -42.8420 - c_gp: 1.3992 - g_loss: 43.4961
# Epoch 265/6000
# 8/8 [==============================] - 2s 282ms/step - c_loss: -29.1270 - c_wass_loss: -41.9746 - c_gp: 1.2848 - g_loss: -24.7959
# Epoch 266/6000
# 8/8 [==============================] - 2s 279ms/step - c_loss: -28.2479 - c_wass_loss: -40.5841 - c_gp: 1.2336 - g_loss: 29.5987
# Epoch 267/6000
# 8/8 [==============================] - 2s 281ms/step - c_loss: -27.5873 - c_wass_loss: -46.1172 - c_gp: 1.8530 - g_loss: 5.6086
# Epoch 268/6000
# 8/8 [==============================] - 2s 279ms/step - c_loss: -23.5041 - c_wass_loss: -42.9314 - c_gp: 1.9427 - g_loss: -71.4671
# Epoch 269/6000
# 8/8 [==============================] - 2s 309ms/step - c_loss: -22.7027 - c_wass_loss: -53.4747 - c_gp: 3.0772 - g_loss: -7.1583
# Epoch 270/6000
# 8/8 [==============================] - 2s 282ms/step - c_loss: -29.2585 - c_wass_loss: -41.3407 - c_gp: 1.2082 - g_loss: -24.3787
# Epoch 271/6000
# 8/8 [==============================] - 2s 312ms/step - c_loss: -28.4345 - c_wass_loss: -42.3649 - c_gp: 1.3930 - g_loss: -38.6069
# Epoch 272/6000
# 8/8 [==============================] - 2s 282ms/step - c_loss: -27.5094 - c_wass_loss: -34.8942 - c_gp: 0.7385 - g_loss: 85.3851
# Epoch 273/6000
# 8/8 [==============================] - 2s 280ms/step - c_loss: -27.9359 - c_wass_loss: -42.6455 - c_gp: 1.4710 - g_loss: 53.9097
# Epoch 274/6000
# 8/8 [==============================] - 2s 282ms/step - c_loss: -29.0060 - c_wass_loss: -38.0875 - c_gp: 0.9081 - g_loss: -30.8462
# Epoch 275/6000
# 8/8 [==============================] - 2s 282ms/step - c_loss: -31.1680 - c_wass_loss: -52.7904 - c_gp: 2.1622 - g_loss: 18.3075
# Epoch 276/6000
# 8/8 [==============================] - 2s 281ms/step - c_loss: -23.6917 - c_wass_loss: -46.1010 - c_gp: 2.2409 - g_loss: 15.6181
# Epoch 277/6000
# 8/8 [==============================] - 2s 282ms/step - c_loss: -26.3212 - c_wass_loss: -42.3297 - c_gp: 1.6008 - g_loss: 26.9253
# Epoch 278/6000
# 8/8 [==============================] - 2s 283ms/step - c_loss: -29.7017 - c_wass_loss: -38.5838 - c_gp: 0.8882 - g_loss: 3.2604
# Epoch 279/6000
# 8/8 [==============================] - 2s 279ms/step - c_loss: -28.5215 - c_wass_loss: -44.9888 - c_gp: 1.6467 - g_loss: -38.3809
# Epoch 280/6000
# 8/8 [==============================] - 2s 322ms/step - c_loss: -23.9175 - c_wass_loss: -45.1167 - c_gp: 2.1199 - g_loss: 3.8703
# Epoch 281/6000
# 8/8 [==============================] - 2s 281ms/step - c_loss: -25.7054 - c_wass_loss: -50.5941 - c_gp: 2.4889 - g_loss: 77.4212
# Epoch 282/6000
# 8/8 [==============================] - 2s 282ms/step - c_loss: -27.5729 - c_wass_loss: -35.3867 - c_gp: 0.7814 - g_loss: 26.5176
# Epoch 283/6000
# 8/8 [==============================] - 2s 285ms/step - c_loss: -29.1367 - c_wass_loss: -38.9683 - c_gp: 0.9832 - g_loss: 21.8990
# Epoch 284/6000
# 8/8 [==============================] - 2s 283ms/step - c_loss: -29.3325 - c_wass_loss: -41.7022 - c_gp: 1.2370 - g_loss: -15.1042
# Epoch 285/6000
# 8/8 [==============================] - 2s 321ms/step - c_loss: -29.8088 - c_wass_loss: -42.0124 - c_gp: 1.2204 - g_loss: 69.6181
# Epoch 286/6000
# 8/8 [==============================] - 2s 285ms/step - c_loss: -28.9797 - c_wass_loss: -40.5195 - c_gp: 1.1540 - g_loss: -36.7564
# Epoch 287/6000
# 8/8 [==============================] - 2s 284ms/step - c_loss: -30.2842 - c_wass_loss: -40.7678 - c_gp: 1.0484 - g_loss: -78.9146
# Epoch 288/6000
# 8/8 [==============================] - 2s 282ms/step - c_loss: -29.3142 - c_wass_loss: -43.9534 - c_gp: 1.4639 - g_loss: 21.2764
# Epoch 289/6000
# 8/8 [==============================] - 2s 281ms/step - c_loss: -28.7446 - c_wass_loss: -43.5835 - c_gp: 1.4839 - g_loss: 7.3369
# Epoch 290/6000
# 8/8 [==============================] - 2s 321ms/step - c_loss: -26.7648 - c_wass_loss: -42.3210 - c_gp: 1.5556 - g_loss: -115.3798
# Epoch 291/6000
# 8/8 [==============================] - 2s 283ms/step - c_loss: -28.3142 - c_wass_loss: -38.2000 - c_gp: 0.9886 - g_loss: -50.8526
# Epoch 292/6000
# 8/8 [==============================] - 2s 282ms/step - c_loss: -32.0772 - c_wass_loss: -40.3121 - c_gp: 0.8235 - g_loss: 19.7429
# Epoch 293/6000
# 8/8 [==============================] - 2s 283ms/step - c_loss: -28.8131 - c_wass_loss: -39.4505 - c_gp: 1.0637 - g_loss: -17.6805
# Epoch 294/6000
# 8/8 [==============================] - 2s 282ms/step - c_loss: -30.6177 - c_wass_loss: -43.8708 - c_gp: 1.3253 - g_loss: -63.0480
# Epoch 295/6000
# 8/8 [==============================] - 2s 309ms/step - c_loss: -27.0688 - c_wass_loss: -43.2927 - c_gp: 1.6224 - g_loss: -12.4707
# Epoch 296/6000
# 8/8 [==============================] - 2s 310ms/step - c_loss: -30.3763 - c_wass_loss: -42.3916 - c_gp: 1.2015 - g_loss: -60.2663
# Epoch 297/6000
# 8/8 [==============================] - 2s 283ms/step - c_loss: -28.2566 - c_wass_loss: -39.1835 - c_gp: 1.0927 - g_loss: 83.1429
# Epoch 298/6000
# 8/8 [==============================] - 2s 281ms/step - c_loss: -29.9859 - c_wass_loss: -41.9846 - c_gp: 1.1999 - g_loss: -81.0317
# Epoch 299/6000
# 8/8 [==============================] - 2s 281ms/step - c_loss: -25.6931 - c_wass_loss: -43.9979 - c_gp: 1.8305 - g_loss: 27.1039
# Epoch 300/6000
# 8/8 [==============================] - 2s 319ms/step - c_loss: -28.1607 - c_wass_loss: -45.4981 - c_gp: 1.7337 - g_loss: -6.8783
# Epoch 301/6000
# 8/8 [==============================] - 2s 280ms/step - c_loss: -26.7478 - c_wass_loss: -41.6113 - c_gp: 1.4864 - g_loss: 17.9436
# Epoch 302/6000
# 8/8 [==============================] - 2s 283ms/step - c_loss: -30.3187 - c_wass_loss: -42.2942 - c_gp: 1.1975 - g_loss: -24.4707
# Epoch 303/6000
# 8/8 [==============================] - 2s 284ms/step - c_loss: -30.0577 - c_wass_loss: -39.1077 - c_gp: 0.9050 - g_loss: -17.9804
# Epoch 304/6000
# 8/8 [==============================] - 2s 283ms/step - c_loss: -30.0299 - c_wass_loss: -39.9567 - c_gp: 0.9927 - g_loss: -133.6547
# Epoch 305/6000
# 8/8 [==============================] - 2s 284ms/step - c_loss: -28.8392 - c_wass_loss: -39.9156 - c_gp: 1.1076 - g_loss: 73.4296
# Epoch 306/6000
# 8/8 [==============================] - 2s 322ms/step - c_loss: -23.7690 - c_wass_loss: -55.5764 - c_gp: 3.1807 - g_loss: -125.2498
# Epoch 307/6000
# 8/8 [==============================] - 2s 282ms/step - c_loss: -28.3871 - c_wass_loss: -45.5349 - c_gp: 1.7148 - g_loss: -33.1747
# Epoch 308/6000
# 8/8 [==============================] - 2s 281ms/step - c_loss: -33.1928 - c_wass_loss: -42.8600 - c_gp: 0.9667 - g_loss: -10.9626
# Epoch 309/6000
# 8/8 [==============================] - 2s 281ms/step - c_loss: -31.4291 - c_wass_loss: -42.1312 - c_gp: 1.0702 - g_loss: 48.8504
# Epoch 310/6000
# 8/8 [==============================] - 2s 284ms/step - c_loss: -18.9599 - c_wass_loss: -52.5365 - c_gp: 3.3577 - g_loss: -49.5532
# Epoch 311/6000
# 8/8 [==============================] - 2s 320ms/step - c_loss: -26.0107 - c_wass_loss: -37.0746 - c_gp: 1.1064 - g_loss: -68.6996
# Epoch 312/6000
# 8/8 [==============================] - 2s 281ms/step - c_loss: -27.2287 - c_wass_loss: -37.6218 - c_gp: 1.0393 - g_loss: 50.6093
# Epoch 313/6000
# 8/8 [==============================] - 2s 283ms/step - c_loss: -25.6769 - c_wass_loss: -35.1691 - c_gp: 0.9492 - g_loss: -62.7455
# Epoch 314/6000
# 8/8 [==============================] - 2s 283ms/step - c_loss: -30.1237 - c_wass_loss: -41.2128 - c_gp: 1.1089 - g_loss: -144.8442
# Epoch 315/6000
# 8/8 [==============================] - 2s 282ms/step - c_loss: -25.7567 - c_wass_loss: -36.5437 - c_gp: 1.0787 - g_loss: -6.3194
# Epoch 316/6000
# 8/8 [==============================] - 2s 321ms/step - c_loss: -28.0132 - c_wass_loss: -39.8803 - c_gp: 1.1867 - g_loss: -37.7849
# Epoch 317/6000
# 8/8 [==============================] - 2s 285ms/step - c_loss: -25.0273 - c_wass_loss: -42.7419 - c_gp: 1.7715 - g_loss: 9.0639
# Epoch 318/6000
# 8/8 [==============================] - 2s 285ms/step - c_loss: -27.4082 - c_wass_loss: -38.2651 - c_gp: 1.0857 - g_loss: -153.8218
# Epoch 319/6000
# 8/8 [==============================] - 2s 282ms/step - c_loss: -26.2984 - c_wass_loss: -38.6382 - c_gp: 1.2340 - g_loss: -24.0757
# Epoch 320/6000
# 8/8 [==============================] - 2s 312ms/step - c_loss: -30.6340 - c_wass_loss: -42.3581 - c_gp: 1.1724 - g_loss: -57.9590
# Epoch 321/6000
# 8/8 [==============================] - 2s 324ms/step - c_loss: -31.5771 - c_wass_loss: -41.0144 - c_gp: 0.9437 - g_loss: -42.2333
# Epoch 322/6000
# 8/8 [==============================] - 2s 281ms/step - c_loss: -28.2197 - c_wass_loss: -37.1881 - c_gp: 0.8968 - g_loss: 29.6231
# Epoch 323/6000
# 8/8 [==============================] - 2s 282ms/step - c_loss: -30.4725 - c_wass_loss: -39.1261 - c_gp: 0.8654 - g_loss: -0.2477
# Epoch 324/6000
# 8/8 [==============================] - 2s 284ms/step - c_loss: -28.5153 - c_wass_loss: -42.8627 - c_gp: 1.4347 - g_loss: -33.5891
# Epoch 325/6000
# 8/8 [==============================] - 2s 284ms/step - c_loss: -27.3647 - c_wass_loss: -39.2662 - c_gp: 1.1902 - g_loss: -7.9354
# Epoch 326/6000
# 8/8 [==============================] - 2s 324ms/step - c_loss: -29.4344 - c_wass_loss: -39.5346 - c_gp: 1.0100 - g_loss: -94.0605
# Epoch 327/6000
# 8/8 [==============================] - 2s 282ms/step - c_loss: -30.9260 - c_wass_loss: -43.9656 - c_gp: 1.3040 - g_loss: 56.1850
# Epoch 328/6000
# 8/8 [==============================] - 2s 285ms/step - c_loss: -26.9419 - c_wass_loss: -37.4003 - c_gp: 1.0458 - g_loss: -7.2502
# Epoch 329/6000
# 8/8 [==============================] - 2s 282ms/step - c_loss: -25.1075 - c_wass_loss: -46.5019 - c_gp: 2.1394 - g_loss: -27.9610
# Epoch 330/6000
# 8/8 [==============================] - 2s 284ms/step - c_loss: -31.6788 - c_wass_loss: -47.5967 - c_gp: 1.5918 - g_loss: -52.9393
# Epoch 331/6000
# ...
# Epoch 5892/6000
# 8/8 [==============================] - 3s 460ms/step - c_loss: -51.5066 - c_wass_loss: -77.9161 - c_gp: 2.6410 - g_loss: -16.6707
# Epoch 5893/6000
# 8/8 [==============================] - 3s 354ms/step - c_loss: -37.0842 - c_wass_loss: -88.0344 - c_gp: 5.0950 - g_loss: -15.2228
# Epoch 5894/6000
# 8/8 [==============================] - 2s 284ms/step - c_loss: -47.3135 - c_wass_loss: -69.2128 - c_gp: 2.1899 - g_loss: -28.6362
# Epoch 5895/6000
# 8/8 [==============================] - 2s 285ms/step - c_loss: -39.6633 - c_wass_loss: -99.6483 - c_gp: 5.9985 - g_loss: -7.1561
# Epoch 5896/6000
# 8/8 [==============================] - 2s 284ms/step - c_loss: -57.6195 - c_wass_loss: -81.9463 - c_gp: 2.4327 - g_loss: -16.1530
# Epoch 5897/6000
# 8/8 [==============================] - 2s 285ms/step - c_loss: -52.1149 - c_wass_loss: -85.1594 - c_gp: 3.3045 - g_loss: -16.1684
# Epoch 5898/6000
# 8/8 [==============================] - 2s 283ms/step - c_loss: -57.0341 - c_wass_loss: -79.4444 - c_gp: 2.2410 - g_loss: -18.8076
# Epoch 5899/6000
# 8/8 [==============================] - 2s 315ms/step - c_loss: -20.3568 - c_wass_loss: -96.2567 - c_gp: 7.5900 - g_loss: -6.6294
# Epoch 5900/6000
# 8/8 [==============================] - 2s 282ms/step - c_loss: -51.4161 - c_wass_loss: -76.0343 - c_gp: 2.4618 - g_loss: -5.1259
# Epoch 5901/6000
# 8/8 [==============================] - 3s 397ms/step - c_loss: -53.2515 - c_wass_loss: -82.0302 - c_gp: 2.8779 - g_loss: -6.6768
# Epoch 5902/6000
# 8/8 [==============================] - 2s 285ms/step - c_loss: -50.6351 - c_wass_loss: -78.4385 - c_gp: 2.7803 - g_loss: -20.0387
# Epoch 5903/6000
# 8/8 [==============================] - 2s 282ms/step - c_loss: -52.8926 - c_wass_loss: -75.7947 - c_gp: 2.2902 - g_loss: -11.6383
# Epoch 5904/6000
# 8/8 [==============================] - 2s 285ms/step - c_loss: -60.0239 - c_wass_loss: -83.6645 - c_gp: 2.3641 - g_loss: -19.7337
# Epoch 5905/6000
# 8/8 [==============================] - 3s 365ms/step - c_loss: -55.2568 - c_wass_loss: -84.5429 - c_gp: 2.9286 - g_loss: -13.8774
# Epoch 5906/6000
# 8/8 [==============================] - 2s 286ms/step - c_loss: -47.2021 - c_wass_loss: -89.0116 - c_gp: 4.1810 - g_loss: -3.6962
# Epoch 5907/6000
# 8/8 [==============================] - 2s 284ms/step - c_loss: -51.6959 - c_wass_loss: -77.5701 - c_gp: 2.5874 - g_loss: -24.9230
# Epoch 5908/6000
# 8/8 [==============================] - 2s 286ms/step - c_loss: -54.1929 - c_wass_loss: -88.2779 - c_gp: 3.4085 - g_loss: -27.3483
# Epoch 5909/6000
# 8/8 [==============================] - 3s 359ms/step - c_loss: -35.0419 - c_wass_loss: -120.4131 - c_gp: 8.5371 - g_loss: -20.7932
# Epoch 5910/6000
# 8/8 [==============================] - 3s 459ms/step - c_loss: -41.2187 - c_wass_loss: -78.2679 - c_gp: 3.7049 - g_loss: -4.4386
# Epoch 5911/6000
# 8/8 [==============================] - 2s 283ms/step - c_loss: -40.2795 - c_wass_loss: -83.1974 - c_gp: 4.2918 - g_loss: -4.0812
# Epoch 5912/6000
# 8/8 [==============================] - 2s 282ms/step - c_loss: -55.3883 - c_wass_loss: -89.7498 - c_gp: 3.4361 - g_loss: -12.2602
# Epoch 5913/6000
# 8/8 [==============================] - 2s 284ms/step - c_loss: -48.2768 - c_wass_loss: -76.6056 - c_gp: 2.8329 - g_loss: -22.6490
# Epoch 5914/6000
# 8/8 [==============================] - 2s 283ms/step - c_loss: -14.4897 - c_wass_loss: -86.3805 - c_gp: 7.1891 - g_loss: -25.5322
# Epoch 5915/6000
# 8/8 [==============================] - 2s 283ms/step - c_loss: -55.8567 - c_wass_loss: -75.9462 - c_gp: 2.0089 - g_loss: -20.7435
# Epoch 5916/6000
# 8/8 [==============================] - 3s 388ms/step - c_loss: -59.6891 - c_wass_loss: -78.1500 - c_gp: 1.8461 - g_loss: -19.4260
# Epoch 5917/6000
# 8/8 [==============================] - 2s 282ms/step - c_loss: -56.0196 - c_wass_loss: -81.1941 - c_gp: 2.5175 - g_loss: -12.8199
# Epoch 5918/6000
# 8/8 [==============================] - 2s 282ms/step - c_loss: -53.4712 - c_wass_loss: -70.7110 - c_gp: 1.7240 - g_loss: -20.4265
# Epoch 5919/6000
# 8/8 [==============================] - 2s 282ms/step - c_loss: -55.7848 - c_wass_loss: -80.5216 - c_gp: 2.4737 - g_loss: -17.0133
# Epoch 5920/6000
# 8/8 [==============================] - 3s 351ms/step - c_loss: -51.0746 - c_wass_loss: -80.4065 - c_gp: 2.9332 - g_loss: -20.4421
# Epoch 5921/6000
# 8/8 [==============================] - 2s 286ms/step - c_loss: -54.6902 - c_wass_loss: -76.2964 - c_gp: 2.1606 - g_loss: -15.9244
# Epoch 5922/6000
# 8/8 [==============================] - 2s 285ms/step - c_loss: -53.7307 - c_wass_loss: -73.6721 - c_gp: 1.9941 - g_loss: -29.0027
# Epoch 5923/6000
# 8/8 [==============================] - 2s 309ms/step - c_loss: -47.3089 - c_wass_loss: -85.0324 - c_gp: 3.7723 - g_loss: -20.7348
# Epoch 5924/6000
# 8/8 [==============================] - 2s 283ms/step - c_loss: -39.8751 - c_wass_loss: -73.4305 - c_gp: 3.3555 - g_loss: -16.3899
# Epoch 5925/6000
# 8/8 [==============================] - 3s 342ms/step - c_loss: -5.4555 - c_wass_loss: -95.9386 - c_gp: 9.0483 - g_loss: -28.1274
# Epoch 5926/6000
# 8/8 [==============================] - 2s 284ms/step - c_loss: -49.9153 - c_wass_loss: -69.4461 - c_gp: 1.9531 - g_loss: -26.2854
# Epoch 5927/6000
# 8/8 [==============================] - 2s 308ms/step - c_loss: -54.9798 - c_wass_loss: -80.5731 - c_gp: 2.5593 - g_loss: -30.4757
# Epoch 5928/6000
# 8/8 [==============================] - 3s 349ms/step - c_loss: -55.7430 - c_wass_loss: -79.7244 - c_gp: 2.3981 - g_loss: -20.8710
# Epoch 5929/6000
# 8/8 [==============================] - 2s 285ms/step - c_loss: -36.1974 - c_wass_loss: -85.0958 - c_gp: 4.8898 - g_loss: -7.5708
# Epoch 5930/6000
# 8/8 [==============================] - 2s 302ms/step - c_loss: -61.4037 - c_wass_loss: -94.6363 - c_gp: 3.3233 - g_loss: -12.0035
# Epoch 5931/6000
# 8/8 [==============================] - 3s 348ms/step - c_loss: -55.4974 - c_wass_loss: -83.9445 - c_gp: 2.8447 - g_loss: -7.4019
# Epoch 5932/6000
# 8/8 [==============================] - 2s 286ms/step - c_loss: -43.6400 - c_wass_loss: -78.7409 - c_gp: 3.5101 - g_loss: -15.0117
# Epoch 5933/6000
# 8/8 [==============================] - 2s 284ms/step - c_loss: -54.5573 - c_wass_loss: -70.3918 - c_gp: 1.5835 - g_loss: -28.5991
# Epoch 5934/6000
# 8/8 [==============================] - 3s 345ms/step - c_loss: -48.1255 - c_wass_loss: -88.0277 - c_gp: 3.9902 - g_loss: -23.6283
# Epoch 5935/6000
# 8/8 [==============================] - 2s 282ms/step - c_loss: -55.6032 - c_wass_loss: -73.1983 - c_gp: 1.7595 - g_loss: -15.8374
# Epoch 5936/6000
# 8/8 [==============================] - 2s 296ms/step - c_loss: -49.1658 - c_wass_loss: -72.6740 - c_gp: 2.3508 - g_loss: -31.8393
# Epoch 5937/6000
# 8/8 [==============================] - 3s 353ms/step - c_loss: -47.9880 - c_wass_loss: -71.6671 - c_gp: 2.3679 - g_loss: -21.9822
# Epoch 5938/6000
# 8/8 [==============================] - 2s 286ms/step - c_loss: -32.0032 - c_wass_loss: -78.1196 - c_gp: 4.6116 - g_loss: -15.8241
# Epoch 5939/6000
# 8/8 [==============================] - 2s 298ms/step - c_loss: -61.2126 - c_wass_loss: -90.7781 - c_gp: 2.9566 - g_loss: -9.2285
# Epoch 5940/6000
# 8/8 [==============================] - 3s 385ms/step - c_loss: -40.4366 - c_wass_loss: -87.8140 - c_gp: 4.7377 - g_loss: 6.2436
# Epoch 5941/6000
# 8/8 [==============================] - 2s 284ms/step - c_loss: -53.7504 - c_wass_loss: -71.4978 - c_gp: 1.7747 - g_loss: -5.5541
# Epoch 5942/6000
# 8/8 [==============================] - 2s 286ms/step - c_loss: -51.8612 - c_wass_loss: -74.7025 - c_gp: 2.2841 - g_loss: -18.5658
# Epoch 5943/6000
# 8/8 [==============================] - 3s 421ms/step - c_loss: -50.1817 - c_wass_loss: -77.0917 - c_gp: 2.6910 - g_loss: -21.0134
# Epoch 5944/6000
# 8/8 [==============================] - 2s 282ms/step - c_loss: -65.8167 - c_wass_loss: -94.6463 - c_gp: 2.8830 - g_loss: -19.2612
# Epoch 5945/6000
# 8/8 [==============================] - 2s 284ms/step - c_loss: -48.5665 - c_wass_loss: -75.5212 - c_gp: 2.6955 - g_loss: 9.2414
# Epoch 5946/6000
# 8/8 [==============================] - 2s 317ms/step - c_loss: -47.2574 - c_wass_loss: -83.0870 - c_gp: 3.5830 - g_loss: -18.2593
# Epoch 5947/6000
# 8/8 [==============================] - 3s 418ms/step - c_loss: -44.6705 - c_wass_loss: -88.5421 - c_gp: 4.3872 - g_loss: -15.6240
# Epoch 5948/6000
# 8/8 [==============================] - 2s 283ms/step - c_loss: -48.3660 - c_wass_loss: -72.5040 - c_gp: 2.4138 - g_loss: -8.3598
# Epoch 5949/6000
# 8/8 [==============================] - 2s 284ms/step - c_loss: -63.6621 - c_wass_loss: -91.9576 - c_gp: 2.8296 - g_loss: 5.0379
# Epoch 5950/6000
# 8/8 [==============================] - 2s 288ms/step - c_loss: -48.0530 - c_wass_loss: -76.2068 - c_gp: 2.8154 - g_loss: -22.7789
# Epoch 5951/6000
# 8/8 [==============================] - 2s 283ms/step - c_loss: -48.7511 - c_wass_loss: -85.5647 - c_gp: 3.6814 - g_loss: -17.1699
# Epoch 5952/6000
# 8/8 [==============================] - 2s 283ms/step - c_loss: -47.0042 - c_wass_loss: -80.0052 - c_gp: 3.3001 - g_loss: -5.8774
# Epoch 5953/6000
# 8/8 [==============================] - 2s 282ms/step - c_loss: -52.5060 - c_wass_loss: -74.4792 - c_gp: 2.1973 - g_loss: -25.3223
# Epoch 5954/6000
# 8/8 [==============================] - 2s 284ms/step - c_loss: -54.8566 - c_wass_loss: -82.4213 - c_gp: 2.7565 - g_loss: -29.2112
# Epoch 5955/6000
# 8/8 [==============================] - 3s 334ms/step - c_loss: -49.6258 - c_wass_loss: -78.0474 - c_gp: 2.8422 - g_loss: 2.8073
# Epoch 5956/6000
# 8/8 [==============================] - 3s 354ms/step - c_loss: -63.1918 - c_wass_loss: -83.9803 - c_gp: 2.0788 - g_loss: -33.2013
# Epoch 5957/6000
# 8/8 [==============================] - 2s 283ms/step - c_loss: -51.1324 - c_wass_loss: -86.9799 - c_gp: 3.5848 - g_loss: -8.7733
# Epoch 5958/6000
# 8/8 [==============================] - 2s 297ms/step - c_loss: -33.5345 - c_wass_loss: -81.4936 - c_gp: 4.7959 - g_loss: -8.2315
# Epoch 5959/6000
# 8/8 [==============================] - 3s 357ms/step - c_loss: -54.1796 - c_wass_loss: -73.2955 - c_gp: 1.9116 - g_loss: -10.4538
# Epoch 5960/6000
# 8/8 [==============================] - 2s 283ms/step - c_loss: -53.9019 - c_wass_loss: -75.5297 - c_gp: 2.1628 - g_loss: -16.2198
# Epoch 5961/6000
# 8/8 [==============================] - 2s 284ms/step - c_loss: -67.9650 - c_wass_loss: -88.7524 - c_gp: 2.0787 - g_loss: -7.2570
# Epoch 5962/6000
# 8/8 [==============================] - 3s 353ms/step - c_loss: -52.3817 - c_wass_loss: -82.6205 - c_gp: 3.0239 - g_loss: 0.1773
# Epoch 5963/6000
# 8/8 [==============================] - 2s 283ms/step - c_loss: 5.5274 - c_wass_loss: -106.6148 - c_gp: 11.2142 - g_loss: -5.6257
# Epoch 5964/6000
# 8/8 [==============================] - 2s 284ms/step - c_loss: -48.4471 - c_wass_loss: -78.5689 - c_gp: 3.0122 - g_loss: 9.4103
# Epoch 5965/6000
# 8/8 [==============================] - 2s 283ms/step - c_loss: -59.5220 - c_wass_loss: -80.0346 - c_gp: 2.0513 - g_loss: -16.7450
# Epoch 5966/6000
# 8/8 [==============================] - 2s 282ms/step - c_loss: -47.5320 - c_wass_loss: -67.8710 - c_gp: 2.0339 - g_loss: -14.3151
# Epoch 5967/6000
# 8/8 [==============================] - 2s 286ms/step - c_loss: -62.1503 - c_wass_loss: -94.2829 - c_gp: 3.2133 - g_loss: -12.2140
# Epoch 5968/6000
# 8/8 [==============================] - 2s 286ms/step - c_loss: -52.3800 - c_wass_loss: -77.3650 - c_gp: 2.4985 - g_loss: -6.2215
# Epoch 5969/6000
# 8/8 [==============================] - 3s 453ms/step - c_loss: -65.8983 - c_wass_loss: -84.9446 - c_gp: 1.9046 - g_loss: -14.8798
# Epoch 5970/6000
# 8/8 [==============================] - 2s 288ms/step - c_loss: -21.9008 - c_wass_loss: -89.7616 - c_gp: 6.7861 - g_loss: -14.1779
# Epoch 5971/6000
# 8/8 [==============================] - 2s 311ms/step - c_loss: -46.4101 - c_wass_loss: -82.8956 - c_gp: 3.6485 - g_loss: -5.9360
# Epoch 5972/6000
# 8/8 [==============================] - 2s 307ms/step - c_loss: -54.9738 - c_wass_loss: -85.7558 - c_gp: 3.0782 - g_loss: -16.4523
# Epoch 5973/6000
# 8/8 [==============================] - 2s 284ms/step - c_loss: -56.0343 - c_wass_loss: -78.4678 - c_gp: 2.2433 - g_loss: 2.5953
# Epoch 5974/6000
# 8/8 [==============================] - 3s 337ms/step - c_loss: -54.9422 - c_wass_loss: -81.7004 - c_gp: 2.6758 - g_loss: 10.9693
# Epoch 5975/6000
# 8/8 [==============================] - 2s 307ms/step - c_loss: -47.5016 - c_wass_loss: -75.1658 - c_gp: 2.7664 - g_loss: -23.3311
# Epoch 5976/6000
# 8/8 [==============================] - 2s 284ms/step - c_loss: -54.5147 - c_wass_loss: -78.0496 - c_gp: 2.3535 - g_loss: -7.3124
# Epoch 5977/6000
# 8/8 [==============================] - 2s 322ms/step - c_loss: -54.8276 - c_wass_loss: -74.7271 - c_gp: 1.9900 - g_loss: -5.0811
# Epoch 5978/6000
# 8/8 [==============================] - 3s 444ms/step - c_loss: -48.0279 - c_wass_loss: -81.8285 - c_gp: 3.3801 - g_loss: -11.9433
# Epoch 5979/6000
# 8/8 [==============================] - 2s 283ms/step - c_loss: -54.1717 - c_wass_loss: -90.1448 - c_gp: 3.5973 - g_loss: -6.4476
# Epoch 5980/6000
# 8/8 [==============================] - 2s 283ms/step - c_loss: -45.7735 - c_wass_loss: -86.8259 - c_gp: 4.1052 - g_loss: -21.9443
# Epoch 5981/6000
# 8/8 [==============================] - 2s 286ms/step - c_loss: -43.3352 - c_wass_loss: -78.2109 - c_gp: 3.4876 - g_loss: 2.2853
# Epoch 5982/6000
# 8/8 [==============================] - 2s 285ms/step - c_loss: -43.1220 - c_wass_loss: -82.2381 - c_gp: 3.9116 - g_loss: -15.8555
# Epoch 5983/6000
# 8/8 [==============================] - 2s 285ms/step - c_loss: -63.4280 - c_wass_loss: -89.5523 - c_gp: 2.6124 - g_loss: -16.5228
# Epoch 5984/6000
# 8/8 [==============================] - 2s 318ms/step - c_loss: -57.2199 - c_wass_loss: -80.6931 - c_gp: 2.3473 - g_loss: -12.7150
# Epoch 5985/6000
# 8/8 [==============================] - 2s 287ms/step - c_loss: -51.4316 - c_wass_loss: -72.1261 - c_gp: 2.0694 - g_loss: -8.3743
# Epoch 5986/6000
# 8/8 [==============================] - 2s 286ms/step - c_loss: -44.8393 - c_wass_loss: -83.7394 - c_gp: 3.8900 - g_loss: -3.7899
# Epoch 5987/6000
# 8/8 [==============================] - 2s 288ms/step - c_loss: -49.2924 - c_wass_loss: -71.2684 - c_gp: 2.1976 - g_loss: -7.5642
# Epoch 5988/6000
# 8/8 [==============================] - 2s 285ms/step - c_loss: -53.7351 - c_wass_loss: -72.4719 - c_gp: 1.8737 - g_loss: -7.4129
# Epoch 5989/6000
# 8/8 [==============================] - 3s 386ms/step - c_loss: 26.6045 - c_wass_loss: -89.8313 - c_gp: 11.6436 - g_loss: -19.6305
# Epoch 5990/6000
# 8/8 [==============================] - 3s 446ms/step - c_loss: -51.2416 - c_wass_loss: -65.9779 - c_gp: 1.4736 - g_loss: -11.6498
# Epoch 5991/6000
# 8/8 [==============================] - 2s 286ms/step - c_loss: -54.4848 - c_wass_loss: -77.9353 - c_gp: 2.3450 - g_loss: -28.5558
# Epoch 5992/6000
# 8/8 [==============================] - 2s 286ms/step - c_loss: -44.8391 - c_wass_loss: -85.2946 - c_gp: 4.0456 - g_loss: 4.9936
# Epoch 5993/6000
# 8/8 [==============================] - 2s 287ms/step - c_loss: -45.2823 - c_wass_loss: -91.0320 - c_gp: 4.5750 - g_loss: -25.9566
# Epoch 5994/6000
# 8/8 [==============================] - 2s 288ms/step - c_loss: -68.9945 - c_wass_loss: -105.8253 - c_gp: 3.6831 - g_loss: 1.2991
# Epoch 5995/6000
# 8/8 [==============================] - 3s 357ms/step - c_loss: -47.6034 - c_wass_loss: -74.4895 - c_gp: 2.6886 - g_loss: 3.8816
# Epoch 5996/6000
# 8/8 [==============================] - 2s 325ms/step - c_loss: -46.3119 - c_wass_loss: -90.6989 - c_gp: 4.4387 - g_loss: 1.8661
# Epoch 5997/6000
# 8/8 [==============================] - 2s 319ms/step - c_loss: -48.7158 - c_wass_loss: -74.3860 - c_gp: 2.5670 - g_loss: -14.9990
# Epoch 5998/6000
# 8/8 [==============================] - 3s 332ms/step - c_loss: -51.4246 - c_wass_loss: -76.9767 - c_gp: 2.5552 - g_loss: -6.2577
# Epoch 5999/6000
# 8/8 [==============================] - 3s 332ms/step - c_loss: -57.7114 - c_wass_loss: -83.4305 - c_gp: 2.5719 - g_loss: -15.1378
# Epoch 6000/6000
# 8/8 [==============================] - 2s 288ms/step - c_loss: -54.5298 - c_wass_loss: -83.7356 - c_gp: 2.9206 - g_loss: -4.6725
# CPU times: user 2h 1min 4s, sys: 16min 17s, total: 2h 17min 22s
# Wall time: 3h 55min 27s

# %% [markdown]
# # Generate new scores

# %%
num_scores = 1
chords_random_latent_vectors = np.random.normal(size=(num_scores, Z_DIM))
style_random_latent_vectors = np.random.normal(size=(num_scores, Z_DIM))
melody_random_latent_vectors = np.random.normal(
    size=(num_scores, N_TRACKS, Z_DIM)
)
groove_random_latent_vectors = np.random.normal(
    size=(num_scores, N_TRACKS, Z_DIM)
)
random_latent_vectors = [
    chords_random_latent_vectors,
    style_random_latent_vectors,
    melody_random_latent_vectors,
    groove_random_latent_vectors,
]
generated_music = generator(random_latent_vectors)
generated_music = generated_music.numpy()

draw_score(generated_music, 0)
notes_to_midi(
    generated_music, N_BARS, N_TRACKS, N_STEPS_PER_BAR, filename="output_midi"
)

# %% [markdown]
# ## Changing Chord Noise

# %%
chords_random_latent_vectors_2 = np.random.normal(size=(num_scores, Z_DIM))
random_latent_vectors_2 = [
    chords_random_latent_vectors_2,
    style_random_latent_vectors,
    melody_random_latent_vectors,
    groove_random_latent_vectors,
]
generated_music_2 = generator(random_latent_vectors_2)
generated_music_2 = generated_music_2.numpy()
draw_score(generated_music_2, 0)
notes_to_midi(
    generated_music_2,
    N_BARS,
    N_TRACKS,
    N_STEPS_PER_BAR,
    filename="output_midi_chords_changed",
)

# %% [markdown]
# # Changing Style Noise

# %%
style_random_latent_vectors_2 = np.random.normal(size=(num_scores, Z_DIM))
random_latent_vectors_3 = [
    chords_random_latent_vectors,
    style_random_latent_vectors_2,
    melody_random_latent_vectors,
    groove_random_latent_vectors,
]
generated_music_3 = generator(random_latent_vectors_3)
generated_music_3 = generated_music_3.numpy()
draw_score(generated_music_3, 0)
notes_to_midi(
    generated_music_3,
    N_BARS,
    N_TRACKS,
    N_STEPS_PER_BAR,
    filename="output_midi_style_changed",
)

# %% [markdown]
# ## Changing Melody Noise

# %%
melody_random_latent_vectors_2 = np.copy(melody_random_latent_vectors)
melody_random_latent_vectors_2[:, 0, :] = np.random.normal(
    size=(num_scores, Z_DIM)
)

random_latent_vectors_4 = [
    chords_random_latent_vectors,
    style_random_latent_vectors,
    melody_random_latent_vectors_2,
    groove_random_latent_vectors,
]
generated_music_4 = generator(random_latent_vectors_4)
generated_music_4 = generated_music_4.numpy()
draw_score(generated_music_4, 0)
notes_to_midi(
    generated_music_4,
    N_BARS,
    N_TRACKS,
    N_STEPS_PER_BAR,
    filename="output_midi_melody_changed",
)

# %% [markdown]
# ## Changing groove noise

# %%
groove_random_latent_vectors_2 = np.copy(groove_random_latent_vectors)
groove_random_latent_vectors_2[:, -1, :] = np.random.normal(
    size=(num_scores, Z_DIM)
)

random_latent_vectors_5 = [
    chords_random_latent_vectors,
    style_random_latent_vectors,
    melody_random_latent_vectors,
    groove_random_latent_vectors_2,
]
generated_music_5 = generator(random_latent_vectors_5)
generated_music_5 = generated_music_5.numpy()
draw_score(generated_music_5, 0)
notes_to_midi(
    generated_music_5,
    N_BARS,
    N_TRACKS,
    N_STEPS_PER_BAR,
    filename="output_midi_groove_changed",
)

# %%
endTime = time.time()

elapsedTime = time.strftime("%H:%M:%S", time.gmtime(endTime - startTime))

print(todaysDate.strftime('# Run Date: %A, %B %d, %Y'))
print(f"# Run Time: {elapsedTime}")
# Out:
# # Run Date: Monday, June 05, 2023
# # Run Time: 03:55:37
